# %% [markdown]
# # Pre-Processing and Modelling
# * ## 2.1 Importing Data
# * ## 2.2 Unsupervised Learning for Temperature
# * ## 1.4 Numerical Data Explorations and Data Evaluations
#  * ### 1.4.1 Visualization of Walmart Stock and SP500
#  * ### 1.4.2 Visualization of Walmart Stock and Weekly Sales
#  * ### 1.4.3 Visualization of Weekly Sales and CPI
#  * ### 1.4.4 Visualization of Weekly Sales and Oil
# * ## 1.5 Distributions of Various Variables
# * ## 1.6 Autocorrelation of Weekly Sales and ADFuller
# * ## 1.7 Correlation Between Numerical Variables and Weekly Sales
# * ## 1.8 Decomposition of Weekly Sales (Time Series)
# * ## 1.9 Heatmap and Correlations Between Variables
# * ## 1.10 Percentage Change Visualizations and Comparisons

# %%
#Load all the necessary packages for the wrangling part of the project
import requests
from pathlib import Path
from eod import EodHistoricalData
from twelvedata import TDClient
import datetime as dt
import pandas as pd
import numpy as np
import numpy.random
import os
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.decomposition import PCA
from sklearn.preprocessing import scale

import pandas as pd
import numpy as np
import os
import pickle
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.cluster import KMeans
from sklearn import __version__ as sklearn_version
from sklearn.decomposition import PCA
from sklearn.preprocessing import scale
from sklearn.metrics import accuracy_score, f1_score

import tensorflow as tf

from sklearn.model_selection import train_test_split, cross_validate, GridSearchCV, learning_curve
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.dummy import DummyRegressor
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor, RandomForestClassifier
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error
from sklearn.pipeline import make_pipeline
from sklearn.impute import SimpleImputer
from sklearn.feature_selection import SelectKBest, f_regression
import datetime

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM, GRU
from keras.layers import Dropout
from sklearn.preprocessing import MinMaxScaler
from keras.models import load_model
from keras.callbacks import EarlyStopping
from keras.callbacks import ModelCheckpoint

# %%
file1 = '../Capstone_Project_3/df_wrangled_1.csv'
file2 = '../Capstone_Project_3/grouped.csv'

# %%
df_1 = pd.read_csv(file1, index_col='Unnamed: 0')
df_2 = pd.read_csv(file2)

# %%
temp = df_1.groupby('Date')[['Holiday_Flag']].agg('max')
df_2 = df_2.merge(temp, left_on ='time', right_on=temp.index)

# %%
df_1.head()
# Out:
#    Store        Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0      1  2010-02-05    1643690.90             0        42.31       2.572
# 1      1  2010-02-12    1641957.44             1        38.51       2.548
# 2      1  2010-02-19    1611968.17             0        39.93       2.514
# 3      1  2010-02-26    1409727.59             0        46.63       2.561
# 4      1  2010-03-05    1554806.68             0        46.50       2.625
#
#           CPI  Unemployment  stock_price    sp500
# 0  211.096358         8.106     53.45000  1066.19
# 1  211.242170         8.106     52.89999  1075.51
# 2  211.289143         8.106     53.49001  1109.17
# 3  211.319643         8.106     54.07001  1104.49
# 4  211.350143         8.106     54.14000  1138.69

# %%
df_2.head()
# Out:
#          time  Weekly_Sales   Walmart    sp500  Temperature  Fuel_Price  \
# 0  2010-02-05   49750740.50  53.45000  1066.19    34.037333    2.717844
# 1  2010-02-12   48336677.63  52.89999  1075.51    34.151333    2.694022
# 2  2010-02-19   48276993.78  53.49001  1109.17    37.719778    2.672067
# 3  2010-02-26   43968571.13  54.07001  1104.49    39.243556    2.683933
# 4  2010-03-05   46871470.30  54.14000  1138.69    42.917333    2.731200
#
#           CPI  Unemployment  Holiday_Flag
# 0  167.730885      8.619311             0
# 1  167.825608      8.619311             1
# 2  167.871686      8.619311             0
# 3  167.909657      8.619311             0
# 4  167.947628      8.619311             0

# %%
#1. Unsupervised to see what cluster each store is in.
#- Could do different models for different stores
#2. Time series - ARIMA Model
#3. Long short term memories

# %% [markdown]
# ## 2.2 Unsupervised Learning for Temperature and Fuel Price

# %% [markdown]
# #### One of the problems we have for this study is that we cannot make a model for every single store, since we do not have enough data to do that. In that case, we could use temperature and fuel price to conduct an unsupervised learning method to differentiate the stores based on temperature and fuel price. The reason for that is we want in an approximate geological location, the temperature and the gas price may be consistent throughotu the region.

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
#We first get the average temp for each year for each state, and make them into variables
df_1['year'] = pd.DatetimeIndex(df_1['Date']).year

# %%
t1 = df_1.groupby(['Store']).agg({'Temperature':'mean', 'Fuel_Price':'mean'})
t2 = df_1.groupby(['Store','year']).agg({'Temperature':'mean', 'Fuel_Price':'mean'})

# %%
from sklearn.cluster import KMeans
import sklearn.cluster
print('The smaller the value of SS is, the better the clustering, which indicates smaller error.')
ss1 = []
ss2 = []
x_cols = t1.to_numpy()
ks = [i for i in range(2,11,1)]

for i in ks:
    model = KMeans(n_clusters=i)
    model.fit(x_cols)
    pred = model.predict(x_cols)   
    ss1.append(model.inertia_)
    
    centers = model.cluster_centers_
    ss2.append(np.sum((x_cols - centers[pred]) ** 2))

_ = plt.figure()
_ = plt.plot(ks, ss1)
_ = plt.xlabel('K-Values')
_ = plt.ylabel('Sum of squared')

_ = plt.figure()
_ = plt.bar(ks, ss2)
_ = plt.xlabel('K-Values')
_ = plt.ylabel('Sum of squared')
# Out:
# The smaller the value of SS is, the better the clustering, which indicates smaller error.

# %%
import matplotlib.cm as cm
from sklearn import metrics as m
sil_s = []

for k in ks:
    fig, ax1 = plt.subplots(1, 1)
    fig.set_size_inches(18, 7)

    # The 1st subplot is the silhouette plot
    # The silhouette coefficient can range from -1, 1 but in this example all
    # lie within [-0.1, 1]
    ax1.set_xlim([-0.1, 1])
    # The (n_clusters+1)*10 is for inserting blank space between silhouette
    # plots of individual clusters, to demarcate them clearly.
    ax1.set_ylim([0, len(x_cols) + ((k) + 1) * 10])
    model_pred = KMeans(n_clusters=k).fit_predict(x_cols)
    sil_s.append(m.silhouette_score(x_cols, labels=KMeans(n_clusters=k).fit_predict(x_cols)))
    sil_samples = m.silhouette_samples(x_cols, model_pred)
    s_v_for_k = []

    y_lower = 10
    for i in range(k):
        
        ith_cluster_silhouette_values = sil_samples[model_pred == i]

        ith_cluster_silhouette_values.sort()

        size_cluster_i = ith_cluster_silhouette_values.shape[0]
        y_upper = y_lower + size_cluster_i

        color = cm.nipy_spectral(float(i) / k)
        ax1.fill_betweenx(
            np.arange(y_lower, y_upper),
            0,
            ith_cluster_silhouette_values,
            facecolor=color,
            edgecolor=color,
            alpha=0.7,
        )

        # Label the silhouette plots with their cluster numbers at the middle
        ax1.text(-0.05, y_lower + 0.5 * size_cluster_i, str(i))

        # Compute the new y_lower for next plot
        y_lower = y_upper + 10  # 10 for the 0 samples
    ax1.set_title("The silhouette plot for the various clusters.")
    ax1.set_xlabel("The silhouette coefficient values")
    ax1.set_ylabel("Cluster label")

    # The vertical line for average silhouette score of all the values
    ax1.axvline(x=np.mean(sil_s), color="red", linestyle="--")

    ax1.set_yticks([])  # Clear the yaxis labels / ticks
    ax1.set_xticks([-0.1, 0, 0.2, 0.4, 0.6, 0.8, 1])

# %%
_ = plt.figure()
_ = plt.plot(ks, sil_s)
_ = plt.xlabel('K-Values')
_ = plt.ylabel('Silhoutte Score')
_ = plt.axhline(y=np.mean(sil_s), c='red', linestyle='--')

# %%
print("It seems like K-Value equals to 3 will generate the best result.")
# Out:
# It seems like K-Value equals to 3 will generate the best result.

# %%
modelK = KMeans(n_clusters=3)
pred = modelK.fit_predict(x_cols)
t1['loc'] = pred

# %% [markdown]
# ## 2.3 SARIMAX Models

# %%
from sklearn.metrics import mean_squared_error
from statsmodels.tsa.arima.model import ARIMA
from sklearn.model_selection import TimeSeriesSplit
from statsmodels.tsa.statespace.sarimax import SARIMAX

# %%
def evaluate_arima_model(data, arima_order):

    split=int(len(data) * 0.8) 
    # Make train and test variables, with 'train, test'
    train, test = data[0:split], data[split:len(data)]
    past=[x for x in train]
    # make predictions
    predictions = list()
    for i in range(len(test)):#timestep-wise comparison between test data and one-step prediction ARIMA model. 
        model = SARIMAX(past, order=arima_order)
        model_fit = model.fit(disp=0)
        future = model_fit.forecast()[0]
        predictions.append(future)
        past.append(test[i])
    # calculate out of sample error
    error = mean_squared_error(test, predictions)
    # Return the error
    return error
# Make a function called evaluate_models to evaluate different ARIMA models with several different p, d, and q values.
def evaluate_models(dataset, p_values, d_values, q_values):
    best_score, best_cfg = float("inf"), None
    # Iterate through p_values
    for p in p_values:
        # Iterate through d_values
        for d in d_values:
            # Iterate through q_values
            for q in q_values:
                # p, d, q iterator variables in that order
                order = (p,d,q)
                try:
                    # Make a variable called mse for the Mean squared error
                    mse = evaluate_arima_model(dataset, order)
                    if mse < best_score:
                        best_score, best_cfg = mse, order
                    print('SARIMAX%s MSE=%.3f' % (order,mse))
                except:
                    continue
    return print('Best SARIMAX%s MSE=%.3f' % (best_cfg, best_score))

# %%
p_values = [x for x in range(0, 3)]
d_values = [x for x in range(0, 3)]
q_values = [x for x in range(0, 3)]

# %%
df_with_loc = df_1.merge(t1, left_on ='Store', right_on=t1.index)

# %%
df_temp = pd.get_dummies(df_with_loc['Store'], prefix='store')
df_with_loc_nostore = df_with_loc.drop('Store', axis=1)
df_temp = df_with_loc_nostore.join(df_temp)
one_hot_loc = pd.get_dummies(df_temp['loc'], prefix='loc')
df_temp.drop('loc', axis=1, inplace=True)
df_temp = df_temp.join(one_hot_loc)

# %%
df_temp_nostore.head()
# Out:
#          Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0  2010-02-05    1643690.90             0        42.31       2.572
# 1  2010-02-12    1641957.44             1        38.51       2.548
# 2  2010-02-19    1611968.17             0        39.93       2.514
# 3  2010-02-26    1409727.59             0        46.63       2.561
# 4  2010-03-05    1554806.68             0        46.50       2.625
#
#           CPI  Unemployment  stock_price    sp500  loc_0  loc_1  loc_2
# 0  211.096358         8.106     53.45000  1066.19      0      1      0
# 1  211.242170         8.106     52.89999  1075.51      0      1      0
# 2  211.289143         8.106     53.49001  1109.17      0      1      0
# 3  211.319643         8.106     54.07001  1104.49      0      1      0
# 4  211.350143         8.106     54.14000  1138.69      0      1      0

# %%
p_values = [x for x in range(0, 3)]
d_values = [x for x in range(0, 3)]
q_values = [x for x in range(0, 3)]

# %%
from statsmodels.tsa.stattools import kpss
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

# Use kpss()
kpss(df_2['Weekly_Sales'], nlags='legacy')
# Out:
# (0.12207666377015824,
#  0.1,
#  14,
#  {'10%': 0.347, '5%': 0.463, '2.5%': 0.574, '1%': 0.739})

# %%
plot_acf(df_2['Weekly_Sales'], zero=False)

# %%
plot_pacf(df_2['Weekly_Sales'], zero=False)

# %%
df_2['Weekly_Sales']
# Out:
# 0      49750740.50
# 1      48336677.63
# 2      48276993.78
# 3      43968571.13
# 4      46871470.30
#           ...
# 134    43734899.40
# 135    47566639.31
# 136    46128514.25
# 137    45122410.57
# 138    45544116.29
# Name: Weekly_Sales, Length: 139, dtype: float64

# %%
from pmdarima.arima import auto_arima

# %%
arima_model = auto_arima(df_2['Weekly_Sales'], start_p = 1, d=1, start_q = 1, 
                          max_p = 5, max_q = 5, max_d=5, m = 12, 
                          start_P = 0, D=1, start_Q=0, max_P=5, max_D=5, max_Q=5,
                          seasonal = True, 
                          trace = True, 
                          error_action ='ignore',   
                          suppress_warnings = True,  
                          stepwise = True, n_fits=50)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(1,1,1)(0,1,0)[12]             : AIC=4343.991, Time=0.13 sec
#  ARIMA(0,1,0)(0,1,0)[12]             : AIC=4363.965, Time=0.02 sec
#  ARIMA(1,1,0)(1,1,0)[12]             : AIC=4318.606, Time=0.10 sec
#  ARIMA(0,1,1)(0,1,1)[12]             : AIC=4299.943, Time=0.15 sec
#  ARIMA(0,1,1)(0,1,0)[12]             : AIC=4341.972, Time=0.04 sec
#  ARIMA(0,1,1)(1,1,1)[12]             : AIC=4301.836, Time=0.16 sec
#  ARIMA(0,1,1)(0,1,2)[12]             : AIC=4301.807, Time=0.31 sec
#  ARIMA(0,1,1)(1,1,0)[12]             : AIC=4316.107, Time=0.08 sec
#  ARIMA(0,1,1)(1,1,2)[12]             : AIC=inf, Time=0.69 sec
#  ARIMA(0,1,0)(0,1,1)[12]             : AIC=4313.439, Time=0.09 sec
#  ARIMA(1,1,1)(0,1,1)[12]             : AIC=4301.813, Time=0.22 sec
#  ARIMA(0,1,2)(0,1,1)[12]             : AIC=4304.256, Time=0.17 sec
#  ARIMA(1,1,0)(0,1,1)[12]             : AIC=4302.590, Time=0.15 sec
#  ARIMA(1,1,2)(0,1,1)[12]             : AIC=4304.959, Time=0.29 sec
#  ARIMA(0,1,1)(0,1,1)[12] intercept   : AIC=4301.755, Time=0.18 sec
#
# Best model:  ARIMA(0,1,1)(0,1,1)[12]
# Total fit time: 2.769 seconds

# %%
size = int(len(df_2) * 0.8)
X_train, X_test = df_2[0:size], df_2[size:len(df_2)]

# %%
model = SARIMAX(X_train['Weekly_Sales'],  
                order = (0, 1, 1),  
                seasonal_order =(0, 1, 1, 12))
result = model.fit() 
result.summary()
# Out:
#  This problem is unconstrained.
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.52175D+01    |proj g|=  1.61621D-01
#
# At iterate    5    f=  1.51498D+01    |proj g|=  1.08899D-01
#
# At iterate   10    f=  1.51382D+01    |proj g|=  2.60734D-06
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3     10     19      1     0     0   2.607D-06   1.514D+01
#   F =   15.138207009449497
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                      SARIMAX Results
# ==========================================================================================
# Dep. Variable:                       Weekly_Sales   No. Observations:                  111
# Model:             SARIMAX(0, 1, 1)x(0, 1, 1, 12)   Log Likelihood               -1680.341
# Date:                            Sat, 13 Aug 2022   AIC                           3366.682
# Time:                                    17:31:29   BIC                           3374.437
# Sample:                                         0   HQIC                          3369.819
#                                             - 111
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ma.L1         -0.3704      0.076     -4.852      0.000      -0.520      -0.221
# ma.S.L12      -0.6280      0.133     -4.740      0.000      -0.888      -0.368
# sigma2      6.079e+13    3.6e-16   1.69e+29      0.000    6.08e+13    6.08e+13
# ===================================================================================
# Ljung-Box (L1) (Q):                   1.24   Jarque-Bera (JB):                75.21
# Prob(Q):                              0.26   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.30   Skew:                            -0.12
# Prob(H) (two-sided):                  0.46   Kurtosis:                         7.29
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 7.15e+45. Standard errors may be unstable.
# """

# %%
#Train prediction
start_index = 0
end_index = len(X_train)-1
train_prediction = result.predict(start_index, end_index) 

#Prediction
start_index = len(X_train)
end_index = len(df_2)-1
prediction = result.predict(start_index, end_index).rename('Predicted Weekly Sales') 
#Rename the column

# plot predictions and actual values 
prediction.plot(legend = True) 
X_test['Weekly_Sales'].plot(legend = True)
# Out:
# <AxesSubplot:>

# %%
df_2_sarimax = df_2.copy()
df_2_sarimax.iloc[start_index:,1] = prediction
df_2_sarimax.head(-5)
# Out:
#            time  Weekly_Sales   Walmart    sp500  Temperature  Fuel_Price  \
# 0    2010-02-05  4.975074e+07  53.45000  1066.19    34.037333    2.717844
# 1    2010-02-12  4.833668e+07  52.89999  1075.51    34.151333    2.694022
# 2    2010-02-19  4.827699e+07  53.49001  1109.17    37.719778    2.672067
# 3    2010-02-26  4.396857e+07  54.07001  1104.49    39.243556    2.683933
# 4    2010-03-05  4.687147e+07  54.14000  1138.69    42.917333    2.731200
# ..          ...           ...       ...      ...          ...         ...
# 129  2012-08-24  4.989899e+07  72.11000  1411.13    74.592889    3.759644
# 130  2012-08-31  5.134260e+07  72.60001  1406.58    77.793556    3.769067
# 131  2012-09-07  5.505439e+07  73.82001  1437.92    78.038667    3.842556
# 132  2012-09-14  4.797048e+07  74.50000  1465.77    70.238222    3.852044
# 133  2012-09-21  4.728370e+07  74.45000  1460.15    67.924889    3.907911
#
#             CPI  Unemployment  Holiday_Flag
# 0    167.730885      8.619311             0
# 1    167.825608      8.619311             1
# 2    167.871686      8.619311             0
# 3    167.909657      8.619311             0
# 4    167.947628      8.619311             0
# ..          ...           ...           ...
# 129  175.833841      7.237333             0
# 130  175.924154      7.237333             0
# 131  176.014468      7.237333             1
# 132  176.110660      7.237333             0
# 133  176.242124      7.237333             0
#
# [134 rows x 9 columns]

# %%
x = df_2.time
fig, ax = plt.subplots(figsize=(10,10))
ax.set_title("Walmart Weekly Sales")
ax.plot(x,df_2['Weekly_Sales'],color='red',label='Actual_Price')
ax.plot(x,df_2_sarimax['Weekly_Sales'],color='blue',label='Predicted_Price')
plt.legend(loc='upper right', fontsize='x-large')

# %% [markdown]
# ## 2.4 LSTM

# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout, LSTM, Concatenate, Input
from tensorflow.keras.optimizers import Adam

# %%
scaler = StandardScaler()

# %%
df_2
# Out:
#            time  Weekly_Sales   Walmart    sp500  Temperature  Fuel_Price  \
# 0    2010-02-05   49750740.50  53.45000  1066.19    34.037333    2.717844
# 1    2010-02-12   48336677.63  52.89999  1075.51    34.151333    2.694022
# 2    2010-02-19   48276993.78  53.49001  1109.17    37.719778    2.672067
# 3    2010-02-26   43968571.13  54.07001  1104.49    39.243556    2.683933
# 4    2010-03-05   46871470.30  54.14000  1138.69    42.917333    2.731200
# ..          ...           ...       ...      ...          ...         ...
# 134  2012-09-28   43734899.40  73.80000  1440.67    68.754444    3.854578
# 135  2012-10-05   47566639.31  75.13000  1460.93    65.973111    3.845222
# 136  2012-10-12   46128514.25  75.81000  1428.59    58.342667    3.896733
# 137  2012-10-19   45122410.57  75.62000  1433.19    60.705333    3.880000
# 138  2012-10-26   45544116.29  75.11000  1411.94    61.051111    3.791489
#
#             CPI  Unemployment  Holiday_Flag
# 0    167.730885      8.619311             0
# 1    167.825608      8.619311             1
# 2    167.871686      8.619311             0
# 3    167.909657      8.619311             0
# 4    167.947628      8.619311             0
# ..          ...           ...           ...
# 134  176.373588      7.237333             0
# 135  176.505052      6.953711             0
# 136  176.636515      6.953711             0
# 137  176.652613      6.953711             0
# 138  176.649482      6.953711             0
#
# [139 rows x 9 columns]

# %%
df_2['time'] = pd.to_datetime(pd.to_datetime(df_2.time, format='%Y-%m-%d').dt.strftime('%Y-%m-%d'))

# %%
df_lstm = df_2.iloc[:,1:df_2.shape[1]]

# %%
df_lstm = scaler.fit_transform(df_lstm)

# %%
df_lstm_train, df_lstm_test = df_lstm[:int(len(df_lstm)*0.8),:], df_lstm[int(len(df_lstm)*0.8):,:]

# %%
#I want to use about 2 months to predict
n_future = 1
n_past = 8

X_train = []
y_train = []

for i in range(n_past, len(df_lstm_train)- n_future +1):
    X_train.append(df_lstm_train[i - n_past:i, 0:df_2.shape[1]])
    y_train.append(df_lstm_train[i + n_future - 1:i + n_future, 0])

# %%
X_test = []
y_test = []
for i in range(n_past, len(df_lstm_test)- n_future +1):
    X_test.append(df_lstm_test[i - n_past:i, 0:df_2.shape[1]])
    y_test.append(df_lstm_test[i + n_future - 1:i + n_future, 0])
    
X_test, y_test = np.array(X_test), np.array(y_test)

# %%
X_train, y_train = np.array(X_train), np.array(y_train)

# %%
X_train.shape
# Out:
# (103, 8, 8)

# %%
y_train.shape
# Out:
# (103, 1)

# %%
fig = plt.figure(figsize=(20,7))
fig.add_subplot(121)
plt.plot(history.epoch, history.history['root_mean_squared_error'], label = "rmse")
plt.plot(history.epoch, history.history['val_root_mean_squared_error'], label = "val_rmse")

plt.title("RMSE", fontsize=18)
plt.xlabel("Epochs", fontsize=15)
plt.ylabel("RMSE", fontsize=15)
plt.grid(alpha=0.3)
plt.legend()

fig.add_subplot(122)

plt.plot(history.epoch, history.history['loss'], label="loss")
plt.plot(history.epoch, history.history['val_loss'], label="val_loss")

plt.title("Loss", fontsize=18)
plt.xlabel("Epochs", fontsize=15)
plt.ylabel("Loss", fontsize=15)
plt.grid(alpha=0.3)
plt.legend()

plt.show()

# %%
#We will have a hyperparameter tuning function for our LSTM. 
#Using a function from Kaggle
def LSTM_HyperParameter_Tuning(x_train, y_train, x_test, y_test, config):

    first_additional_layer, second_additional_layer, n_neurons, n_batch_size, dropout = config
    possible_combinations = [i for i in itertools.product(first_additional_layer, second_additional_layer,
                                                  n_neurons, n_batch_size, dropout)]

    print(possible_combinations)
    print('\n')
    
    hist = []
    
    for i in range(0, len(possible_combinations)):
        
        print(f'No.{i+1} combination: \n')
        print('--------------------------------------------------------------------')
        
        first_additional_layer, second_additional_layer, n_neurons, n_batch_size, dropout = possible_combinations[i]
        
        # instantiating the model in the strategy scope creates the model on the TPU
        #with tpu_strategy.scope():
        regressor = Sequential()
        regressor.add(LSTM(units=n_neurons, return_sequences=True, input_shape=(x_train.shape[1], x_train.shape[2])))
        regressor.add(Dropout(dropout))
        

        if first_additional_layer:
            regressor.add(LSTM(units=n_neurons, return_sequences=True))
            regressor.add(Dropout(dropout))

        if second_additional_layer:
            regressor.add(LSTM(units=n_neurons, return_sequences=True))
            regressor.add(Dropout(dropout))

        regressor.add(LSTM(units=n_neurons, return_sequences=False))
        regressor.add(Dropout(dropout))
        regressor.add(Dense(y_train.shape[1], activation='linear'))
        regressor.compile(optimizer='adam', loss='mse', metrics=[tf.keras.metrics.RootMeanSquaredError()])

        es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=7)

        file_path = 'best_model.h5'

        mc = ModelCheckpoint(file_path, monitor='val_loss', mode='min', verbose=1, save_best_only=True)


        regressor.fit(x_train, y_train, validation_split=0.1, epochs=10, batch_size=n_batch_size, callbacks=[es,mc], verbose=0)

        # load the best model
        # regressor = load_model('best_model.h5')

        train_accuracy = regressor.evaluate(x_train, y_train, verbose=0)
        test_accuracy = regressor.evaluate(x_test, y_test, verbose=0)

        hist.append([i for i in (first_additional_layer, second_additional_layer, n_neurons, n_batch_size, dropout,
                          train_accuracy, test_accuracy)])

        print(f'{str(i)}-th combination = {possible_combinations[i]} \n train accuracy: {train_accuracy} and test accuracy: {test_accuracy}')
        
        print('--------------------------------------------------------------------')
        print('--------------------------------------------------------------------')
    return hist

# %%
import itertools

# %%
config = [[True,False], [False], [16, 32, 64], [4, 8, 16], [0.1, 0.2]] 
hist = LSTM_HyperParameter_Tuning(X_train, y_train, X_test, y_test,config)
# Out:
# [(True, False, 16, 4, 0.1), (True, False, 16, 4, 0.2), (True, False, 16, 8, 0.1), (True, False, 16, 8, 0.2), (True, False, 16, 16, 0.1), (True, False, 16, 16, 0.2), (True, False, 32, 4, 0.1), (True, False, 32, 4, 0.2), (True, False, 32, 8, 0.1), (True, False, 32, 8, 0.2), (True, False, 32, 16, 0.1), (True, False, 32, 16, 0.2), (True, False, 64, 4, 0.1), (True, False, 64, 4, 0.2), (True, False, 64, 8, 0.1), (True, False, 64, 8, 0.2), (True, False, 64, 16, 0.1), (True, False, 64, 16, 0.2), (False, False, 16, 4, 0.1), (False, False, 16, 4, 0.2), (False, False, 16, 8, 0.1), (False, False, 16, 8, 0.2), (False, False, 16, 16, 0.1), (False, False, 16, 16, 0.2), (False, False, 32, 4, 0.1), (False, False, 32, 4, 0.2), (False, False, 32, 8, 0.1), (False, False, 32, 8, 0.2), (False, False, 32, 16, 0.1), (False, False, 32, 16, 0.2), (False, False, 64, 4, 0.1), (False, False, 64, 4, 0.2), (False, False, 64, 8, 0.1), (False, False, 64, 8, 0.2), (False, False, 64, 16, 0.1), (False, False, 64, 16, 0.2)]
#
#
# No.1 combination:
#
# --------------------------------------------------------------------
#
# Epoch 1: val_loss improved from inf to 0.33990, saving model to best_model.h5
#
# Epoch 2: val_loss did not improve from 0.33990
#
# Epoch 3: val_loss did not improve from 0.33990
#
# Epoch 4: val_loss did not improve from 0.33990
#
# Epoch 5: val_loss did not improve from 0.33990
#
# Epoch 6: val_loss did not improve from 0.33990
#
# Epoch 7: val_loss did not improve from 0.33990
#
# Epoch 8: val_loss did not improve from 0.33990
# Epoch 8: early stopping
# 0-th combination = (True, False, 16, 4, 0.1)
#  train accuracy: [1.0791845321655273, 1.0388380289077759] and test accuracy: [3.0640788078308105, 1.7504510879516602]
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# No.2 combination:
#
# --------------------------------------------------------------------
#
# Epoch 1: val_loss improved from inf to 0.35060, saving model to best_model.h5
#
# Epoch 2: val_loss did not improve from 0.35060
#
# Epoch 3: val_loss did not improve from 0.35060
#
# Epoch 4: val_loss did not improve from 0.35060
#
# Epoch 5: val_loss did not improve from 0.35060
#
# Epoch 6: val_loss did not improve from 0.35060
#
# Epoch 7: val_loss did not improve from 0.35060
#
# Epoch 8: val_loss did not improve from 0.35060
# Epoch 8: early stopping
# 1-th combination = (True, False, 16, 4, 0.2)
#  train accuracy: [1.138372540473938, 1.0669454336166382] and test accuracy: [2.8047807216644287, 1.6747479438781738]
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# No.3 combination:
#
# --------------------------------------------------------------------
#
# Epoch 1: val_loss improved from inf to 0.33395, saving model to best_model.h5
#
# Epoch 2: val_loss did not improve from 0.33395
#
# Epoch 3: val_loss did not improve from 0.33395
#
# Epoch 4: val_loss did not improve from 0.33395
#
# Epoch 5: val_loss did not improve from 0.33395
#
# Epoch 6: val_loss did not improve from 0.33395
#
# Epoch 7: val_loss did not improve from 0.33395
#
# Epoch 8: val_loss did not improve from 0.33395
# Epoch 8: early stopping
# 2-th combination = (True, False, 16, 8, 0.1)
#  train accuracy: [1.0487706661224365, 1.024095058441162] and test accuracy: [1.0175482034683228, 1.0087358951568604]
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# No.4 combination:
#
# --------------------------------------------------------------------
#
# Epoch 1: val_loss improved from inf to 0.43214, saving model to best_model.h5
#
# Epoch 2: val_loss did not improve from 0.43214
#
# Epoch 3: val_loss did not improve from 0.43214
#
# Epoch 4: val_loss did not improve from 0.43214
#
# Epoch 5: val_loss did not improve from 0.43214
#
# Epoch 6: val_loss did not improve from 0.43214
#
# Epoch 7: val_loss did not improve from 0.43214
#
# Epoch 8: val_loss did not improve from 0.43214
# Epoch 8: early stopping
# 3-th combination = (True, False, 16, 8, 0.2)
#  train accuracy: [1.1706410646438599, 1.0819616317749023] and test accuracy: [1.0843580961227417, 1.0413252115249634]
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# No.5 combination:
#
# --------------------------------------------------------------------
#
# Epoch 1: val_loss improved from inf to 0.33707, saving model to best_model.h5
#
# Epoch 2: val_loss did not improve from 0.33707
#
# Epoch 3: val_loss did not improve from 0.33707
#
# Epoch 4: val_loss did not improve from 0.33707
#
# Epoch 5: val_loss did not improve from 0.33707
#
# Epoch 6: val_loss did not improve from 0.33707
#
# Epoch 7: val_loss did not improve from 0.33707
#
# Epoch 8: val_loss did not improve from 0.33707
# Epoch 8: early stopping
# 4-th combination = (True, False, 16, 16, 0.1)
#  train accuracy: [1.2223560810089111, 1.1056021451950073] and test accuracy: [0.19344010949134827, 0.43981826305389404]
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# No.6 combination:
#
# --------------------------------------------------------------------
#
# Epoch 1: val_loss improved from inf to 0.35196, saving model to best_model.h5
#
# Epoch 2: val_loss did not improve from 0.35196
#
# Epoch 3: val_loss did not improve from 0.35196
#
# Epoch 4: val_loss did not improve from 0.35196
#
# Epoch 5: val_loss did not improve from 0.35196
#
# Epoch 6: val_loss did not improve from 0.35196
#
# Epoch 7: val_loss did not improve from 0.35196
#
# Epoch 8: val_loss did not improve from 0.35196
# Epoch 8: early stopping
# 5-th combination = (True, False, 16, 16, 0.2)
#  train accuracy: [1.168051838874817, 1.0807644128799438] and test accuracy: [0.13658849895000458, 0.3695788085460663]
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# No.7 combination:
#
# --------------------------------------------------------------------
#
# Epoch 1: val_loss improved from inf to 0.35715, saving model to best_model.h5
#
# Epoch 2: val_loss did not improve from 0.35715
#
# Epoch 3: val_loss did not improve from 0.35715
#
# Epoch 4: val_loss did not improve from 0.35715
#
# Epoch 5: val_loss did not improve from 0.35715
#
# Epoch 6: val_loss did not improve from 0.35715
#
# Epoch 7: val_loss did not improve from 0.35715
#
# Epoch 8: val_loss did not improve from 0.35715
# Epoch 8: early stopping
# 6-th combination = (True, False, 32, 4, 0.1)
#  train accuracy: [1.1783268451690674, 1.0855076313018799] and test accuracy: [6.310067653656006, 2.5119848251342773]
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# No.8 combination:
#
# --------------------------------------------------------------------
#
# Epoch 1: val_loss improved from inf to 0.35775, saving model to best_model.h5
#
# Epoch 2: val_loss did not improve from 0.35775
#
# Epoch 3: val_loss did not improve from 0.35775
#
# Epoch 4: val_loss did not improve from 0.35775
#
# Epoch 5: val_loss did not improve from 0.35775
#
# Epoch 6: val_loss did not improve from 0.35775
#
# Epoch 7: val_loss did not improve from 0.35775
#
# Epoch 8: val_loss did not improve from 0.35775
# Epoch 8: early stopping
# 7-th combination = (True, False, 32, 4, 0.2)
#  train accuracy: [1.2301002740859985, 1.1090989112854004] and test accuracy: [8.873988151550293, 2.978924036026001]
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# No.9 combination:
#
# --------------------------------------------------------------------
#
# Epoch 1: val_loss improved from inf to 0.31473, saving model to best_model.h5
#
# Epoch 2: val_loss did not improve from 0.31473
#
# Epoch 3: val_loss did not improve from 0.31473
#
# Epoch 4: val_loss did not improve from 0.31473
#
# Epoch 5: val_loss did not improve from 0.31473
#
# Epoch 6: val_loss did not improve from 0.31473
#
# Epoch 7: val_loss did not improve from 0.31473
#
# Epoch 8: val_loss did not improve from 0.31473
# Epoch 8: early stopping
# 8-th combination = (True, False, 32, 8, 0.1)
#  train accuracy: [1.0810847282409668, 1.0397522449493408] and test accuracy: [4.928843975067139, 2.220099925994873]
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# No.10 combination:
#
# --------------------------------------------------------------------
# Epoch 1: val_loss improved from inf to 0.33800, saving model to best_model.h5
#
# Epoch 2: val_loss did not improve from 0.33800
#
# Epoch 3: val_loss did not improve from 0.33800
#
# Epoch 4: val_loss did not improve from 0.33800
#
# Epoch 5: val_loss did not improve from 0.33800
#
# Epoch 6: val_loss did not improve from 0.33800
#
# Epoch 7: val_loss did not improve from 0.33800
#
# Epoch 8: val_loss did not improve from 0.33800
# Epoch 8: early stopping
# 9-th combination = (True, False, 32, 8, 0.2)
#  train accuracy: [1.1402220726013184, 1.0678118467330933] and test accuracy: [2.394289493560791, 1.547349214553833]
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# No.11 combination:
#
# --------------------------------------------------------------------
#
# Epoch 1: val_loss improved from inf to 0.32413, saving model to best_model.h5
#
# Epoch 2: val_loss did not improve from 0.32413
#
# Epoch 3: val_loss did not improve from 0.32413
#
# Epoch 4: val_loss did not improve from 0.32413
#
# Epoch 5: val_loss did not improve from 0.32413
#
# Epoch 6: val_loss did not improve from 0.32413
#
# Epoch 7: val_loss did not improve from 0.32413
#
# Epoch 8: val_loss did not improve from 0.32413
# Epoch 8: early stopping
# 10-th combination = (True, False, 32, 16, 0.1)
#  train accuracy: [1.0811264514923096, 1.0397722721099854] and test accuracy: [0.5793703198432922, 0.7611637711524963]
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# No.12 combination:
#
# --------------------------------------------------------------------
#
# Epoch 1: val_loss improved from inf to 0.34350, saving model to best_model.h5
#
# Epoch 2: val_loss did not improve from 0.34350
#
# Epoch 3: val_loss did not improve from 0.34350
#
# Epoch 4: val_loss did not improve from 0.34350
#
# Epoch 5: val_loss did not improve from 0.34350
#
# Epoch 6: val_loss did not improve from 0.34350
#
# Epoch 7: val_loss did not improve from 0.34350
#
# Epoch 8: val_loss did not improve from 0.34350
# Epoch 8: early stopping
# 11-th combination = (True, False, 32, 16, 0.2)
#  train accuracy: [1.087364673614502, 1.0427677631378174] and test accuracy: [1.7266172170639038, 1.314008116722107]
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# No.13 combination:
#
# --------------------------------------------------------------------
#
# Epoch 1: val_loss improved from inf to 0.34870, saving model to best_model.h5
#
# Epoch 2: val_loss did not improve from 0.34870
#
# Epoch 3: val_loss did not improve from 0.34870
#
# Epoch 4: val_loss did not improve from 0.34870
#
# Epoch 5: val_loss did not improve from 0.34870
#
# Epoch 6: val_loss did not improve from 0.34870
#
# Epoch 7: val_loss did not improve from 0.34870
#
# Epoch 8: val_loss did not improve from 0.34870
# Epoch 8: early stopping
# 12-th combination = (True, False, 64, 4, 0.1)
#  train accuracy: [1.0697057247161865, 1.0342657566070557] and test accuracy: [5.6443352699279785, 2.3757810592651367]
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# No.14 combination:
#
# --------------------------------------------------------------------
#
# Epoch 1: val_loss improved from inf to 0.41922, saving model to best_model.h5
#
# Epoch 2: val_loss did not improve from 0.41922
#
# Epoch 3: val_loss did not improve from 0.41922
#
# Epoch 4: val_loss did not improve from 0.41922
#
# Epoch 5: val_loss did not improve from 0.41922
#
# Epoch 6: val_loss did not improve from 0.41922
#
# Epoch 7: val_loss did not improve from 0.41922
#
# Epoch 8: val_loss did not improve from 0.41922
# Epoch 8: early stopping
# 13-th combination = (True, False, 64, 4, 0.2)
#  train accuracy: [1.106588363647461, 1.0519450902938843] and test accuracy: [4.637326717376709, 2.153445243835449]
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# No.15 combination:
#
# --------------------------------------------------------------------
#
# Epoch 1: val_loss improved from inf to 0.33229, saving model to best_model.h5
#
# Epoch 2: val_loss did not improve from 0.33229
#
# Epoch 3: val_loss did not improve from 0.33229
#
# Epoch 4: val_loss did not improve from 0.33229
#
# Epoch 5: val_loss did not improve from 0.33229
#
# Epoch 6: val_loss did not improve from 0.33229
#
# Epoch 7: val_loss did not improve from 0.33229
#
# Epoch 8: val_loss did not improve from 0.33229
# Epoch 8: early stopping
# 14-th combination = (True, False, 64, 8, 0.1)
#  train accuracy: [1.528014063835144, 1.2361286878585815] and test accuracy: [11.086080551147461, 3.3295767307281494]
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# No.16 combination:
#
# --------------------------------------------------------------------
#
# Epoch 1: val_loss improved from inf to 0.36522, saving model to best_model.h5
#
# Epoch 2: val_loss did not improve from 0.36522
#
# Epoch 3: val_loss did not improve from 0.36522
#
# Epoch 4: val_loss did not improve from 0.36522
#
# Epoch 5: val_loss did not improve from 0.36522
#
# Epoch 6: val_loss did not improve from 0.36522
#
# Epoch 7: val_loss did not improve from 0.36522
#
# Epoch 8: val_loss did not improve from 0.36522
# Epoch 8: early stopping
# 15-th combination = (True, False, 64, 8, 0.2)
#  train accuracy: [1.5733540058135986, 1.2543340921401978] and test accuracy: [14.7471284866333, 3.8401989936828613]
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# No.17 combination:
#
# --------------------------------------------------------------------
#
# Epoch 1: val_loss improved from inf to 0.36560, saving model to best_model.h5
#
# Epoch 2: val_loss did not improve from 0.36560
#
# Epoch 3: val_loss did not improve from 0.36560
#
# Epoch 4: val_loss did not improve from 0.36560
#
# Epoch 5: val_loss did not improve from 0.36560
#
# Epoch 6: val_loss did not improve from 0.36560
#
# Epoch 7: val_loss did not improve from 0.36560
#
# Epoch 8: val_loss did not improve from 0.36560
# Epoch 8: early stopping
# 16-th combination = (True, False, 64, 16, 0.1)
#  train accuracy: [1.265723705291748, 1.1250438690185547] and test accuracy: [7.240927219390869, 2.690896987915039]
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# No.18 combination:
#
# --------------------------------------------------------------------
#
# Epoch 1: val_loss improved from inf to 0.33230, saving model to best_model.h5
#
# Epoch 2: val_loss did not improve from 0.33230
#
# Epoch 3: val_loss did not improve from 0.33230
#
# Epoch 4: val_loss did not improve from 0.33230
#
# Epoch 5: val_loss did not improve from 0.33230
#
# Epoch 6: val_loss did not improve from 0.33230
#
# Epoch 7: val_loss did not improve from 0.33230
#
# Epoch 8: val_loss did not improve from 0.33230
# Epoch 8: early stopping
# 17-th combination = (True, False, 64, 16, 0.2)
#  train accuracy: [1.5023466348648071, 1.2257025241851807] and test accuracy: [8.068132400512695, 2.8404457569122314]
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# No.19 combination:
#
# --------------------------------------------------------------------
#
# Epoch 1: val_loss improved from inf to 0.45918, saving model to best_model.h5
#
# Epoch 2: val_loss did not improve from 0.45918
#
# Epoch 3: val_loss did not improve from 0.45918
#
# Epoch 4: val_loss did not improve from 0.45918
#
# Epoch 5: val_loss did not improve from 0.45918
#
# Epoch 6: val_loss did not improve from 0.45918
#
# Epoch 7: val_loss did not improve from 0.45918
#
# Epoch 8: val_loss did not improve from 0.45918
# Epoch 8: early stopping
# 18-th combination = (False, False, 16, 4, 0.1)
#  train accuracy: [1.1802085638046265, 1.086374044418335] and test accuracy: [3.404921770095825, 1.845242977142334]
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# No.20 combination:
#
# --------------------------------------------------------------------
# Epoch 1: val_loss improved from inf to 0.43378, saving model to best_model.h5
#
# Epoch 2: val_loss did not improve from 0.43378
#
# Epoch 3: val_loss did not improve from 0.43378
#
# Epoch 4: val_loss did not improve from 0.43378
#
# Epoch 5: val_loss did not improve from 0.43378
#
# Epoch 6: val_loss did not improve from 0.43378
#
# Epoch 7: val_loss did not improve from 0.43378
#
# Epoch 8: val_loss did not improve from 0.43378
# Epoch 8: early stopping
# 19-th combination = (False, False, 16, 4, 0.2)
#  train accuracy: [1.1399900913238525, 1.067703127861023] and test accuracy: [0.8803234100341797, 0.9382554888725281]
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# No.21 combination:
#
# --------------------------------------------------------------------
#
# Epoch 1: val_loss improved from inf to 0.33522, saving model to best_model.h5
#
# Epoch 2: val_loss did not improve from 0.33522
#
# Epoch 3: val_loss did not improve from 0.33522
#
# Epoch 4: val_loss did not improve from 0.33522
#
# Epoch 5: val_loss did not improve from 0.33522
#
# Epoch 6: val_loss did not improve from 0.33522
#
# Epoch 7: val_loss did not improve from 0.33522
#
# Epoch 8: val_loss did not improve from 0.33522
# Epoch 8: early stopping
# 20-th combination = (False, False, 16, 8, 0.1)
#  train accuracy: [1.1022461652755737, 1.0498790740966797] and test accuracy: [0.13485297560691833, 0.36722332239151]
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# No.22 combination:
#
# --------------------------------------------------------------------
#
# Epoch 1: val_loss improved from inf to 0.49710, saving model to best_model.h5
#
# Epoch 2: val_loss did not improve from 0.49710
#
# Epoch 3: val_loss did not improve from 0.49710
#
# Epoch 4: val_loss did not improve from 0.49710
#
# Epoch 5: val_loss did not improve from 0.49710
#
# Epoch 6: val_loss did not improve from 0.49710
#
# Epoch 7: val_loss did not improve from 0.49710
#
# Epoch 8: val_loss did not improve from 0.49710
# Epoch 8: early stopping
# 21-th combination = (False, False, 16, 8, 0.2)
#  train accuracy: [1.18925940990448, 1.0905317068099976] and test accuracy: [0.8552064895629883, 0.9247737526893616]
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# No.23 combination:
#
# --------------------------------------------------------------------
#
# Epoch 1: val_loss improved from inf to 0.33245, saving model to best_model.h5
#
# Epoch 2: val_loss did not improve from 0.33245
#
# Epoch 3: val_loss did not improve from 0.33245
#
# Epoch 4: val_loss did not improve from 0.33245
#
# Epoch 5: val_loss did not improve from 0.33245
#
# Epoch 6: val_loss did not improve from 0.33245
#
# Epoch 7: val_loss did not improve from 0.33245
#
# Epoch 8: val_loss did not improve from 0.33245
# Epoch 8: early stopping
# 22-th combination = (False, False, 16, 16, 0.1)
#  train accuracy: [1.199525237083435, 1.0952284336090088] and test accuracy: [0.5046838521957397, 0.7104110717773438]
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# No.24 combination:
#
# --------------------------------------------------------------------
#
# Epoch 1: val_loss improved from inf to 0.28436, saving model to best_model.h5
#
# Epoch 2: val_loss did not improve from 0.28436
#
# Epoch 3: val_loss did not improve from 0.28436
#
# Epoch 4: val_loss did not improve from 0.28436
#
# Epoch 5: val_loss did not improve from 0.28436
#
# Epoch 6: val_loss did not improve from 0.28436
#
# Epoch 7: val_loss did not improve from 0.28436
#
# Epoch 8: val_loss did not improve from 0.28436
# Epoch 8: early stopping
# 23-th combination = (False, False, 16, 16, 0.2)
#  train accuracy: [1.1874674558639526, 1.089709758758545] and test accuracy: [0.1926528960466385, 0.4389224350452423]
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# No.25 combination:
#
# --------------------------------------------------------------------
#
# Epoch 1: val_loss improved from inf to 0.40857, saving model to best_model.h5
#
# Epoch 2: val_loss did not improve from 0.40857
#
# Epoch 3: val_loss did not improve from 0.40857
#
# Epoch 4: val_loss did not improve from 0.40857
#
# Epoch 5: val_loss did not improve from 0.40857
#
# Epoch 6: val_loss did not improve from 0.40857
#
# Epoch 7: val_loss did not improve from 0.40857
#
# Epoch 8: val_loss did not improve from 0.40857
# Epoch 8: early stopping
# 24-th combination = (False, False, 32, 4, 0.1)
#  train accuracy: [1.0403167009353638, 1.0199592113494873] and test accuracy: [1.9579368829727173, 1.3992630243301392]
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# No.26 combination:
#
# --------------------------------------------------------------------
#
# Epoch 1: val_loss improved from inf to 0.38239, saving model to best_model.h5
#
# Epoch 2: val_loss did not improve from 0.38239
#
# Epoch 3: val_loss did not improve from 0.38239
#
# Epoch 4: val_loss did not improve from 0.38239
#
# Epoch 5: val_loss did not improve from 0.38239
#
# Epoch 6: val_loss did not improve from 0.38239
#
# Epoch 7: val_loss did not improve from 0.38239
#
# Epoch 8: val_loss did not improve from 0.38239
# Epoch 8: early stopping
# 25-th combination = (False, False, 32, 4, 0.2)
#  train accuracy: [1.2029811143875122, 1.0968049764633179] and test accuracy: [4.8229756355285645, 2.196127414703369]
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# No.27 combination:
#
# --------------------------------------------------------------------
#
# Epoch 1: val_loss improved from inf to 0.33788, saving model to best_model.h5
#
# Epoch 2: val_loss did not improve from 0.33788
#
# Epoch 3: val_loss did not improve from 0.33788
#
# Epoch 4: val_loss did not improve from 0.33788
#
# Epoch 5: val_loss did not improve from 0.33788
#
# Epoch 6: val_loss did not improve from 0.33788
#
# Epoch 7: val_loss did not improve from 0.33788
#
# Epoch 8: val_loss did not improve from 0.33788
# Epoch 8: early stopping
# 26-th combination = (False, False, 32, 8, 0.1)
#  train accuracy: [1.04098641872406, 1.0202873945236206] and test accuracy: [1.8390823602676392, 1.3561277389526367]
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# No.28 combination:
#
# --------------------------------------------------------------------
#
# Epoch 1: val_loss improved from inf to 0.32761, saving model to best_model.h5
#
# Epoch 2: val_loss did not improve from 0.32761
#
# Epoch 3: val_loss did not improve from 0.32761
#
# Epoch 4: val_loss did not improve from 0.32761
#
# Epoch 5: val_loss did not improve from 0.32761
#
# Epoch 6: val_loss did not improve from 0.32761
#
# Epoch 7: val_loss did not improve from 0.32761
#
# Epoch 8: val_loss did not improve from 0.32761
# Epoch 8: early stopping
# 27-th combination = (False, False, 32, 8, 0.2)
#  train accuracy: [1.0434894561767578, 1.0215133428573608] and test accuracy: [1.528008222579956, 1.2361263036727905]
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# No.29 combination:
#
# --------------------------------------------------------------------
#
# Epoch 1: val_loss improved from inf to 0.36871, saving model to best_model.h5
#
# Epoch 2: val_loss did not improve from 0.36871
#
# Epoch 3: val_loss did not improve from 0.36871
#
# Epoch 4: val_loss did not improve from 0.36871
#
# Epoch 5: val_loss did not improve from 0.36871
#
# Epoch 6: val_loss did not improve from 0.36871
#
# Epoch 7: val_loss did not improve from 0.36871
#
# Epoch 8: val_loss did not improve from 0.36871
# Epoch 8: early stopping
# 28-th combination = (False, False, 32, 16, 0.1)
#  train accuracy: [1.1387577056884766, 1.067125916481018] and test accuracy: [0.739916980266571, 0.8601842522621155]
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# No.30 combination:
#
# --------------------------------------------------------------------
# Epoch 1: val_loss improved from inf to 0.33756, saving model to best_model.h5
#
# Epoch 2: val_loss did not improve from 0.33756
#
# Epoch 3: val_loss did not improve from 0.33756
#
# Epoch 4: val_loss did not improve from 0.33756
#
# Epoch 5: val_loss did not improve from 0.33756
#
# Epoch 6: val_loss did not improve from 0.33756
#
# Epoch 7: val_loss did not improve from 0.33756
#
# Epoch 8: val_loss did not improve from 0.33756
# Epoch 8: early stopping
# 29-th combination = (False, False, 32, 16, 0.2)
#  train accuracy: [1.1386849880218506, 1.0670918226242065] and test accuracy: [0.23518404364585876, 0.4849577844142914]
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# No.31 combination:
#
# --------------------------------------------------------------------
#
# Epoch 1: val_loss improved from inf to 0.34414, saving model to best_model.h5
#
# Epoch 2: val_loss did not improve from 0.34414
#
# Epoch 3: val_loss did not improve from 0.34414
#
# Epoch 4: val_loss did not improve from 0.34414
#
# Epoch 5: val_loss did not improve from 0.34414
#
# Epoch 6: val_loss did not improve from 0.34414
#
# Epoch 7: val_loss did not improve from 0.34414
#
# Epoch 8: val_loss did not improve from 0.34414
# Epoch 8: early stopping
# 30-th combination = (False, False, 64, 4, 0.1)
#  train accuracy: [0.9932246804237366, 0.9966065883636475] and test accuracy: [4.479074478149414, 2.116382360458374]
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# No.32 combination:
#
# --------------------------------------------------------------------
#
# Epoch 1: val_loss improved from inf to 0.37964, saving model to best_model.h5
#
# Epoch 2: val_loss did not improve from 0.37964
#
# Epoch 3: val_loss did not improve from 0.37964
#
# Epoch 4: val_loss did not improve from 0.37964
#
# Epoch 5: val_loss did not improve from 0.37964
#
# Epoch 6: val_loss did not improve from 0.37964
#
# Epoch 7: val_loss did not improve from 0.37964
#
# Epoch 8: val_loss did not improve from 0.37964
# Epoch 8: early stopping
# 31-th combination = (False, False, 64, 4, 0.2)
#  train accuracy: [1.183478832244873, 1.0878781080245972] and test accuracy: [5.966806411743164, 2.442704677581787]
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# No.33 combination:
#
# --------------------------------------------------------------------
#
# Epoch 1: val_loss improved from inf to 0.40634, saving model to best_model.h5
#
# Epoch 2: val_loss did not improve from 0.40634
#
# Epoch 3: val_loss did not improve from 0.40634
#
# Epoch 4: val_loss did not improve from 0.40634
#
# Epoch 5: val_loss did not improve from 0.40634
#
# Epoch 6: val_loss did not improve from 0.40634
#
# Epoch 7: val_loss did not improve from 0.40634
#
# Epoch 8: val_loss did not improve from 0.40634
# Epoch 8: early stopping
# 32-th combination = (False, False, 64, 8, 0.1)
#  train accuracy: [1.0677227973937988, 1.0333067178726196] and test accuracy: [3.5304229259490967, 1.8789420127868652]
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# No.34 combination:
#
# --------------------------------------------------------------------
#
# Epoch 1: val_loss improved from inf to 0.36689, saving model to best_model.h5
#
# Epoch 2: val_loss did not improve from 0.36689
#
# Epoch 3: val_loss did not improve from 0.36689
#
# Epoch 4: val_loss did not improve from 0.36689
#
# Epoch 5: val_loss did not improve from 0.36689
#
# Epoch 6: val_loss did not improve from 0.36689
#
# Epoch 7: val_loss did not improve from 0.36689
#
# Epoch 8: val_loss did not improve from 0.36689
# Epoch 8: early stopping
# 33-th combination = (False, False, 64, 8, 0.2)
#  train accuracy: [1.1211671829223633, 1.0588518381118774] and test accuracy: [4.972111225128174, 2.229823112487793]
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# No.35 combination:
#
# --------------------------------------------------------------------
#
# Epoch 1: val_loss improved from inf to 0.43918, saving model to best_model.h5
#
# Epoch 2: val_loss did not improve from 0.43918
#
# Epoch 3: val_loss did not improve from 0.43918
#
# Epoch 4: val_loss did not improve from 0.43918
#
# Epoch 5: val_loss did not improve from 0.43918
#
# Epoch 6: val_loss did not improve from 0.43918
#
# Epoch 7: val_loss did not improve from 0.43918
#
# Epoch 8: val_loss did not improve from 0.43918
# Epoch 8: early stopping
# 34-th combination = (False, False, 64, 16, 0.1)
#  train accuracy: [1.0259432792663574, 1.0128885507583618] and test accuracy: [1.636566162109375, 1.2792834043502808]
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# No.36 combination:
#
# --------------------------------------------------------------------
#
# Epoch 1: val_loss improved from inf to 0.35994, saving model to best_model.h5
#
# Epoch 2: val_loss did not improve from 0.35994
#
# Epoch 3: val_loss did not improve from 0.35994
#
# Epoch 4: val_loss did not improve from 0.35994
#
# Epoch 5: val_loss did not improve from 0.35994
#
# Epoch 6: val_loss did not improve from 0.35994
#
# Epoch 7: val_loss did not improve from 0.35994
#
# Epoch 8: val_loss did not improve from 0.35994
# Epoch 8: early stopping
# 35-th combination = (False, False, 64, 16, 0.2)
#  train accuracy: [1.0347564220428467, 1.0172297954559326] and test accuracy: [1.3333287239074707, 1.1546984910964966]
# --------------------------------------------------------------------
# --------------------------------------------------------------------

# %%
df_lstm_models = pd.DataFrame(hist)
df_lstm_models = df_lstm_models.sort_values(by=[6], ascending=True)
df_lstm_models = df_lstm_models.rename(columns={0:'First_Additional', 1:"Second_Additional", 2:"n_neurons",3: "n_batch_size", 4:"dropout",5:"Train_Acc",6:"Test_Acc"})

# %%
best = df_lstm_models.iloc[0,:]
print(best)
# Out:
# First_Additional                                        False
# Second_Additional                                       False
# n_neurons                                                  16
# n_batch_size                                                8
# dropout                                                   0.1
# Train_Acc            [1.1022461652755737, 1.0498790740966797]
# Test_Acc              [0.13485297560691833, 0.36722332239151]
# Name: 20, dtype: object

# %%
lstm_df = pd.DataFrame(best)
lstm_df = lstm_df.to_csv(r'../Capstone_Project_3/best_lstm.csv')

# %%
print('The above model is the best model we have.')
# Out:
# The above model is the best model we have.

# %%
first_additional_layer, second_additional_layer, n_neurons, n_batch_size, dropout = [i for i in df_lstm_models.iloc[0, :-2]]

# %%
regressor = Sequential()
regressor.add(LSTM(units=n_neurons, return_sequences=True, input_shape=(X_train.shape[1], X_train.shape[2])))
regressor.add(Dropout(dropout))

if first_additional_layer:
    regressor.add(LSTM(units=n_neurons, return_sequences=True))
    regressor.add(Dropout(dropout))

if second_additional_layer:
    regressor.add(LSTM(units=n_neurons, return_sequences=True))
    regressor.add(Dropout(dropout))

regressor.add(LSTM(units=n_neurons, return_sequences=False))
regressor.add(Dropout(dropout))
regressor.add(Dense(units=1, activation='linear'))
regressor.compile(optimizer='adam', loss='mse')

es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=5)

file_path = 'best_model.h5'

mc = ModelCheckpoint(file_path, monitor='val_loss', mode='min', verbose=1, save_best_only=True)

regressor.fit(X_train, y_train, validation_split=0.3, epochs=40, batch_size=n_batch_size, callbacks=[es, mc], verbose=0)
# Out:
# Epoch 1: val_loss improved from inf to 2.63020, saving model to best_model.h5
#
# Epoch 2: val_loss did not improve from 2.63020
#
# Epoch 3: val_loss did not improve from 2.63020
#
# Epoch 4: val_loss did not improve from 2.63020
#
# Epoch 5: val_loss did not improve from 2.63020
#
# Epoch 6: val_loss did not improve from 2.63020
# Epoch 6: early stopping

# %%
regressor.evaluate(X_test, y_test)
# Out:
# 1/1 [==============================] - 0s 23ms/step - loss: 0.1674
# 0.1674082726240158

# %%
y_pred = regressor.predict(X_test)

plt.figure(figsize=(16,8), dpi= 100, facecolor='w', edgecolor='k')

plt.plot(y_test, color='red', label = 'Real Weekly Sale')
plt.plot(y_pred, color='green', label = 'Predicted Weekly Sale')
plt.legend(loc='best')

# %%
prediction_copies = np.repeat(y_pred, df_lstm_train.shape[1], axis=-1)
y_pred_future = scaler.inverse_transform(prediction_copies)[:,0]

# %%
y_pred_future
# Out:
# array([46303432., 46182776., 46012416., 45867800., 45761956., 45620440.,
#        45574036., 45538120., 45598228., 45655112., 45720108., 45766868.,
#        45855224., 45849648., 45778424., 45748544., 45786996., 45862264.,
#        45893464., 45931824.], dtype=float32)

# %%
df_2.iloc[-20:,1] =
# Out:
# (20,)

# %%
df_2
# Out:
#           time  Weekly_Sales   Walmart    sp500  Temperature  Fuel_Price  \
# 0   2010-02-05  4.975074e+07  53.45000  1066.19    34.037333    2.717844
# 1   2010-02-12  4.833668e+07  52.89999  1075.51    34.151333    2.694022
# 2   2010-02-19  4.827699e+07  53.49001  1109.17    37.719778    2.672067
# 3   2010-02-26  4.396857e+07  54.07001  1104.49    39.243556    2.683933
# 4   2010-03-05  4.687147e+07  54.14000  1138.69    42.917333    2.731200
# ..         ...           ...       ...      ...          ...         ...
# 134 2012-09-28  1.674705e-01  73.80000  1440.67    68.754444    3.854578
# 135 2012-10-05 -1.422799e-01  75.13000  1460.93    65.973111    3.845222
# 136 2012-10-12 -3.589794e-01  75.81000  1428.59    58.342667    3.896733
# 137 2012-10-19 -2.681504e-01  75.62000  1433.19    60.705333    3.880000
# 138 2012-10-26  4.554412e+07  75.11000  1411.94    61.051111    3.791489
#
#             CPI  Unemployment  Holiday_Flag
# 0    167.730885      8.619311             0
# 1    167.825608      8.619311             1
# 2    167.871686      8.619311             0
# 3    167.909657      8.619311             0
# 4    167.947628      8.619311             0
# ..          ...           ...           ...
# 134  176.373588      7.237333             0
# 135  176.505052      6.953711             0
# 136  176.636515      6.953711             0
# 137  176.652613      6.953711             0
# 138  176.649482      6.953711             0
#
# [139 rows x 9 columns]

# %%
df_2_copy = df_2.copy()

# %%
y_pred_future.shape
# Out:
# (20,)

# %%
df_pred_lstm.iloc[119:, 1] = y_pred_future

# %%
x = df_2.time
fig, ax = plt.subplots(figsize=(10,10))
ax.set_title("Walmart Weekly Sales")
ax.plot(x,df_2['Weekly_Sales'],color='red',label='Actual_Price')
ax.plot(x,df_pred_lstm['Weekly_Sales'],color='blue',label='Predicted_Price')
plt.legend(loc='upper right', fontsize='x-large')

# %% [markdown]
# ## 2.5 LSTM with Multiple Inputs

# %%
df_loc0 = df_temp_nostore[df_temp_nostore['loc_0']==1].groupby('Date').agg({'Weekly_Sales':'sum', 'Temperature':'mean','Fuel_Price':'mean','CPI':'mean','Unemployment':'mean','stock_price':'mean','sp500':'mean', 'Holiday_Flag':'min'})
df_loc1 = df_temp_nostore[df_temp_nostore['loc_1']==1].groupby('Date').agg({'Weekly_Sales':'sum', 'Temperature':'mean','Fuel_Price':'mean','CPI':'mean','Unemployment':'mean','stock_price':'mean','sp500':'mean', 'Holiday_Flag':'min'})
df_loc2 = df_temp_nostore[df_temp_nostore['loc_2']==1].groupby('Date').agg({'Weekly_Sales':'sum', 'Temperature':'mean','Fuel_Price':'mean','CPI':'mean','Unemployment':'mean','stock_price':'mean','sp500':'mean', 'Holiday_Flag':'min'})

# %%
df_loc0.head()
# Out:
#             Weekly_Sales  Temperature  Fuel_Price         CPI  Unemployment  \
# Date
# 2010-02-05    6250488.53    17.568571    2.681429  155.595838         7.202
# 2010-02-12    6265671.91    20.842857    2.671429  155.664131         7.202
# 2010-02-19    6064603.77    24.965714    2.649286  155.719941         7.202
# 2010-02-26    5598828.76    24.832857    2.669143  155.773670         7.202
# 2010-03-05    6089456.73    32.054286    2.691286  155.827400         7.202
#
#             stock_price    sp500  Holiday_Flag
# Date
# 2010-02-05     53.45000  1066.19             0
# 2010-02-12     52.89999  1075.51             1
# 2010-02-19     53.49001  1109.17             0
# 2010-02-26     54.07001  1104.49             0
# 2010-03-05     54.14000  1138.69             0

# %%
x = df_loc0.index
fig, ax = plt.subplots(figsize=(10,10))
ax.set_title("Walmart Weekly Sales")
ax.plot(x,df_loc0['Weekly_Sales'],color='red',label='LOC_0')
ax.plot(x,df_loc1['Weekly_Sales'],color='blue',label='LOC_1')
ax.plot(x,df_loc2['Weekly_Sales'],color='black',label='LOC_2')

plt.legend(loc='upper right', fontsize='x-large')

# %% [markdown]
# ### A key insight from this graph is that based on temperature and gas price, walmart stores's weekly sales follow similar patterns, but their weekly sales are siginificantly different.

# %%
df_loc0['Total_WS'] = df_loc0['Weekly_Sales'] + df_loc1['Weekly_Sales'] + df_loc2['Weekly_Sales']
df_loc1['Total_WS'] = df_loc0['Weekly_Sales'] + df_loc1['Weekly_Sales'] + df_loc2['Weekly_Sales']
df_loc2['Total_WS'] = df_loc0['Weekly_Sales'] + df_loc1['Weekly_Sales'] + df_loc2['Weekly_Sales']

# %%
y = df_loc0['Total_WS']

# %%
loc0=df_loc0.iloc[:, :-1]
loc1=df_loc1.iloc[:, :-1]
loc2=df_loc2.iloc[:, :-1]

# %%
loc0 = loc0.reset_index().drop(columns='Date')

# %%
loc1 = loc1.reset_index().drop(columns='Date')
loc2 = loc2.reset_index().drop(columns='Date')

# %%
scaler0 = StandardScaler()
loc0 = scaler0.fit_transform(loc0)

# %%
#I want to use about 2 months to predict
n_future = 1
n_past = 8

X_train0 = []
y_train0 = []

loc0_tr, loc0_te = loc0[:int(len(loc0)*0.8),:], loc0[int(len(loc0)*0.8):,:]

for i in range(n_past, len(loc0_tr)- n_future +1):
    X_train0.append(loc0_tr[i - n_past:i, 0:loc0.shape[1]])
    y_train0.append(loc0_tr[i + n_future - 1:i + n_future, 0])
    
X_test0 = []
y_test0 = []
for i in range(n_past, len(loc0_te)- n_future +1):
    X_test0.append(loc0_te[i - n_past:i, 0:loc0_te.shape[1]])
    y_test0.append(loc0_te[i + n_future - 1:i + n_future, 0])

X_train0, y_train0 = np.array(X_train0), np.array(y_train0)
X_test0, y_test0 = np.array(X_test0), np.array(y_test0)

# %%
scaler1 = StandardScaler()
loc1 = scaler1.fit_transform(loc1)
#I want to use about 2 months to predict
n_future = 1
n_past = 8

X_train1 = []
y_train1 = []

loc1_tr, loc1_te = loc1[:int(len(loc1)*0.8),:], loc1[int(len(loc1)*0.8):,:]

for i in range(n_past, len(loc1_tr)- n_future +1):
    X_train1.append(loc1_tr[i - n_past:i, 0:loc1.shape[1]])
    y_train1.append(loc1_tr[i + n_future - 1:i + n_future, 0])
    
X_test1 = []
y_test1 = []
for i in range(n_past, len(loc1_te)- n_future +1):
    X_test1.append(loc1_te[i - n_past:i, 0:loc1_te.shape[1]])
    y_test1.append(loc1_te[i + n_future - 1:i + n_future, 0])

X_train1, y_train1 = np.array(X_train1), np.array(y_train1)
X_test1, y_test1 = np.array(X_test1), np.array(y_test1)

# %%
scaler2 = StandardScaler()
loc2 = scaler2.fit_transform(loc1)
#I want to use about 2 months to predict
n_future = 1
n_past = 8

X_train2 = []
y_train2 = []

loc2_tr, loc2_te = loc2[:int(len(loc2)*0.8),:], loc1[int(len(loc2)*0.8):,:]

for i in range(n_past, len(loc2_tr)- n_future +1):
    X_train2.append(loc2_tr[i - n_past:i, 0:loc2.shape[1]])
    y_train2.append(loc2_tr[i + n_future - 1:i + n_future, 0])
    
X_test2 = []
y_test2 = []
for i in range(n_past, len(loc2_te)- n_future +1):
    X_test2.append(loc2_te[i - n_past:i, 0:loc2_te.shape[1]])
    y_test2.append(loc2_te[i + n_future - 1:i + n_future, 0])

X_train2, y_train2 = np.array(X_train2), np.array(y_train2)
X_test2, y_test2 = np.array(X_test2), np.array(y_test2)

# %%
#We will have a hyperparameter tuning function for our LSTM. 
#Using a function from Kaggle
def LSTM_HyperParameter_Tuning_con(x_train, y_train, x_test, y_test, config):

    first_additional_layer, second_additional_layer, n_neurons, n_batch_size, dropout = config
    possible_combinations = [i for i in itertools.product(first_additional_layer, second_additional_layer,
                                                  n_neurons, n_batch_size, dropout)]

    print(possible_combinations)
    print('\n')
    
    hist = []
    
    for i in range(0, len(possible_combinations)):
        
        print(f'No.{i+1} combination: \n')
        print('--------------------------------------------------------------------')
        
        first_additional_layer, second_additional_layer, n_neurons, n_batch_size, dropout = possible_combinations[i]
        
        # instantiating the model in the strategy scope creates the model on the TPU
        #with tpu_strategy.scope():
        regressor = Sequential()
        regressor.add(LSTM(units=n_neurons, return_sequences=True, input_shape=(x_train.shape[1], x_train.shape[2])))
        regressor.add(Dropout(dropout))
        

        if first_additional_layer:
            regressor.add(LSTM(units=n_neurons, return_sequences=True))
            regressor.add(Dropout(dropout))

        if second_additional_layer:
            regressor.add(LSTM(units=n_neurons, return_sequences=True))
            regressor.add(Dropout(dropout))

        regressor.add(LSTM(units=n_neurons, return_sequences=False))
        regressor.add(Dropout(dropout))
        regressor.add(Dense(y_train.shape[1], activation='linear'))
        regressor.compile(optimizer='adam', loss='mse', metrics=[tf.keras.metrics.RootMeanSquaredError()])

        es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=4)

        file_path = 'best_model.h6'

        mc = ModelCheckpoint(file_path, monitor='val_loss', mode='min', verbose=1, save_best_only=True)


        regressor.fit(x_train, y_train, validation_split=0.1, epochs=10, batch_size=n_batch_size, callbacks=[es,mc], verbose=0)

        # load the best model
        # regressor = load_model('best_model.h5')

        train_accuracy = regressor.evaluate(x_train, y_train, verbose=0)
        test_accuracy = regressor.evaluate(x_test, y_test, verbose=0)

        hist.append([i for i in (first_additional_layer, second_additional_layer, n_neurons, n_batch_size, dropout,
                          train_accuracy, test_accuracy)])

        print(f'{str(i)}-th combination = {possible_combinations[i]} \n train accuracy: {train_accuracy} and test accuracy: {test_accuracy}')
        
        print('--------------------------------------------------------------------')
        print('--------------------------------------------------------------------')
    return hist

# %%
config0 = [[True,False],[False], [8,16], [4, 8], [0.1, 0.2]]
hist0 = LSTM_HyperParameter_Tuning_con(X_train0, y_train0, X_test0, y_test0,config0)  # change x_train shape
# Out:
# [(True, False, 8, 4, 0.1), (True, False, 8, 4, 0.2), (True, False, 8, 8, 0.1), (True, False, 8, 8, 0.2), (True, False, 16, 4, 0.1), (True, False, 16, 4, 0.2), (True, False, 16, 8, 0.1), (True, False, 16, 8, 0.2), (False, False, 8, 4, 0.1), (False, False, 8, 4, 0.2), (False, False, 8, 8, 0.1), (False, False, 8, 8, 0.2), (False, False, 16, 4, 0.1), (False, False, 16, 4, 0.2), (False, False, 16, 8, 0.1), (False, False, 16, 8, 0.2)]
#
#
# No.1 combination:
#
# --------------------------------------------------------------------
#
# Epoch 1: val_loss did not improve from inf
#
# Epoch 2: val_loss did not improve from inf
#
# Epoch 3: val_loss did not improve from inf
#
# Epoch 4: val_loss did not improve from inf
# Epoch 4: early stopping
# 0-th combination = (True, False, 8, 4, 0.1)
#  train accuracy: [nan, nan] and test accuracy: [nan, nan]
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# No.2 combination:
#
# --------------------------------------------------------------------
#
# Epoch 1: val_loss did not improve from inf
#
# Epoch 2: val_loss did not improve from inf
#
# Epoch 3: val_loss did not improve from inf
#
# Epoch 4: val_loss did not improve from inf
# Epoch 4: early stopping
# 1-th combination = (True, False, 8, 4, 0.2)
#  train accuracy: [nan, nan] and test accuracy: [nan, nan]
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# No.3 combination:
#
# --------------------------------------------------------------------
#
# Epoch 1: val_loss did not improve from inf
#
# Epoch 2: val_loss did not improve from inf
#
# Epoch 3: val_loss did not improve from inf
#
# Epoch 4: val_loss did not improve from inf
# Epoch 4: early stopping
# 2-th combination = (True, False, 8, 8, 0.1)
#  train accuracy: [nan, nan] and test accuracy: [nan, nan]
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# No.4 combination:
#
# --------------------------------------------------------------------
#
# Epoch 1: val_loss did not improve from inf
#
# Epoch 2: val_loss did not improve from inf
#
# Epoch 3: val_loss did not improve from inf
#
# Epoch 4: val_loss did not improve from inf
# Epoch 4: early stopping
# 3-th combination = (True, False, 8, 8, 0.2)
#  train accuracy: [nan, nan] and test accuracy: [nan, nan]
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# No.5 combination:
#
# --------------------------------------------------------------------
#
# Epoch 1: val_loss did not improve from inf
#
# Epoch 2: val_loss did not improve from inf
#
# Epoch 3: val_loss did not improve from inf
#
# Epoch 4: val_loss did not improve from inf
# Epoch 4: early stopping
# 4-th combination = (True, False, 16, 4, 0.1)
#  train accuracy: [nan, nan] and test accuracy: [nan, nan]
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# No.6 combination:
#
# --------------------------------------------------------------------
#
# Epoch 1: val_loss did not improve from inf
#
# Epoch 2: val_loss did not improve from inf
#
# Epoch 3: val_loss did not improve from inf
#
# Epoch 4: val_loss did not improve from inf
# Epoch 4: early stopping
# 5-th combination = (True, False, 16, 4, 0.2)
#  train accuracy: [nan, nan] and test accuracy: [nan, nan]
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# No.7 combination:
#
# --------------------------------------------------------------------
#
# Epoch 1: val_loss did not improve from inf
#
# Epoch 2: val_loss did not improve from inf
#
# Epoch 3: val_loss did not improve from inf
#
# Epoch 4: val_loss did not improve from inf
# Epoch 4: early stopping
# 6-th combination = (True, False, 16, 8, 0.1)
#  train accuracy: [nan, nan] and test accuracy: [nan, nan]
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# No.8 combination:
#
# --------------------------------------------------------------------
#
# Epoch 1: val_loss did not improve from inf
#
# Epoch 2: val_loss did not improve from inf
#
# Epoch 3: val_loss did not improve from inf
#
# Epoch 4: val_loss did not improve from inf
# Epoch 4: early stopping
# 7-th combination = (True, False, 16, 8, 0.2)
#  train accuracy: [nan, nan] and test accuracy: [nan, nan]
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# No.9 combination:
#
# --------------------------------------------------------------------
#
# Epoch 1: val_loss did not improve from inf
#
# Epoch 2: val_loss did not improve from inf
#
# Epoch 3: val_loss did not improve from inf
#
# Epoch 4: val_loss did not improve from inf
# Epoch 4: early stopping
# 8-th combination = (False, False, 8, 4, 0.1)
#  train accuracy: [nan, nan] and test accuracy: [nan, nan]
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# No.10 combination:
#
# --------------------------------------------------------------------
#
# Epoch 1: val_loss did not improve from inf
#
# Epoch 2: val_loss did not improve from inf
#
# Epoch 3: val_loss did not improve from inf
#
# Epoch 4: val_loss did not improve from inf
# Epoch 4: early stopping
# 9-th combination = (False, False, 8, 4, 0.2)
#  train accuracy: [nan, nan] and test accuracy: [nan, nan]
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# No.11 combination:
#
# --------------------------------------------------------------------
#
# Epoch 1: val_loss did not improve from inf
#
# Epoch 2: val_loss did not improve from inf
#
# Epoch 3: val_loss did not improve from inf
#
# Epoch 4: val_loss did not improve from inf
# Epoch 4: early stopping
# 10-th combination = (False, False, 8, 8, 0.1)
#  train accuracy: [nan, nan] and test accuracy: [nan, nan]
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# No.12 combination:
#
# --------------------------------------------------------------------
#
# Epoch 1: val_loss did not improve from inf
#
# Epoch 2: val_loss did not improve from inf
#
# Epoch 3: val_loss did not improve from inf
#
# Epoch 4: val_loss did not improve from inf
# Epoch 4: early stopping
# 11-th combination = (False, False, 8, 8, 0.2)
#  train accuracy: [nan, nan] and test accuracy: [nan, nan]
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# No.13 combination:
#
# --------------------------------------------------------------------
#
# Epoch 1: val_loss did not improve from inf
#
# Epoch 2: val_loss did not improve from inf
#
# Epoch 3: val_loss did not improve from inf
#
# Epoch 4: val_loss did not improve from inf
# Epoch 4: early stopping
# 12-th combination = (False, False, 16, 4, 0.1)
#  train accuracy: [nan, nan] and test accuracy: [nan, nan]
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# No.14 combination:
#
# --------------------------------------------------------------------
#
# Epoch 1: val_loss did not improve from inf
#
# Epoch 2: val_loss did not improve from inf
#
# Epoch 3: val_loss did not improve from inf
#
# Epoch 4: val_loss did not improve from inf
# Epoch 4: early stopping
# 13-th combination = (False, False, 16, 4, 0.2)
#  train accuracy: [nan, nan] and test accuracy: [nan, nan]
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# No.15 combination:
#
# --------------------------------------------------------------------
#
# Epoch 1: val_loss did not improve from inf
#
# Epoch 2: val_loss did not improve from inf
#
# Epoch 3: val_loss did not improve from inf
#
# Epoch 4: val_loss did not improve from inf
# Epoch 4: early stopping
# 14-th combination = (False, False, 16, 8, 0.1)
#  train accuracy: [nan, nan] and test accuracy: [nan, nan]
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# No.16 combination:
#
# --------------------------------------------------------------------
# Epoch 1: val_loss did not improve from inf
#
# Epoch 2: val_loss did not improve from inf
#
# Epoch 3: val_loss did not improve from inf
#
# Epoch 4: val_loss did not improve from inf
# Epoch 4: early stopping
# 15-th combination = (False, False, 16, 8, 0.2)
#  train accuracy: [nan, nan] and test accuracy: [nan, nan]
# --------------------------------------------------------------------
# --------------------------------------------------------------------

# %%
config1 = [[True,False], [False], [16, 32, 64], [4, 8, 16], [0.1, 0.2]] 
hist1 = LSTM_HyperParameter_Tuning(X_train1, y_train1, X_test1, y_test1,config1)  # change x_train shape
# Out:
# [(True, False, 16, 4, 0.1), (True, False, 16, 4, 0.2), (True, False, 16, 8, 0.1), (True, False, 16, 8, 0.2), (True, False, 16, 16, 0.1), (True, False, 16, 16, 0.2), (True, False, 32, 4, 0.1), (True, False, 32, 4, 0.2), (True, False, 32, 8, 0.1), (True, False, 32, 8, 0.2), (True, False, 32, 16, 0.1), (True, False, 32, 16, 0.2), (True, False, 64, 4, 0.1), (True, False, 64, 4, 0.2), (True, False, 64, 8, 0.1), (True, False, 64, 8, 0.2), (True, False, 64, 16, 0.1), (True, False, 64, 16, 0.2), (False, False, 16, 4, 0.1), (False, False, 16, 4, 0.2), (False, False, 16, 8, 0.1), (False, False, 16, 8, 0.2), (False, False, 16, 16, 0.1), (False, False, 16, 16, 0.2), (False, False, 32, 4, 0.1), (False, False, 32, 4, 0.2), (False, False, 32, 8, 0.1), (False, False, 32, 8, 0.2), (False, False, 32, 16, 0.1), (False, False, 32, 16, 0.2), (False, False, 64, 4, 0.1), (False, False, 64, 4, 0.2), (False, False, 64, 8, 0.1), (False, False, 64, 8, 0.2), (False, False, 64, 16, 0.1), (False, False, 64, 16, 0.2)]
#
#
# No.1 combination:
#
# --------------------------------------------------------------------
#
# Epoch 1: val_loss did not improve from inf
#
# Epoch 2: val_loss did not improve from inf
#
# Epoch 3: val_loss did not improve from inf
#
# Epoch 4: val_loss did not improve from inf
#
# Epoch 5: val_loss did not improve from inf
#
# Epoch 6: val_loss did not improve from inf
#
# Epoch 7: val_loss did not improve from inf
# Epoch 7: early stopping
# 0-th combination = (True, False, 16, 4, 0.1)
#  train accuracy: [nan, nan] and test accuracy: [nan, nan]
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# No.2 combination:
#
# --------------------------------------------------------------------
#
# Epoch 1: val_loss did not improve from inf
#
# Epoch 2: val_loss did not improve from inf
#
# Epoch 3: val_loss did not improve from inf
#
# Epoch 4: val_loss did not improve from inf
#
# Epoch 5: val_loss did not improve from inf
#
# Epoch 6: val_loss did not improve from inf
#
# Epoch 7: val_loss did not improve from inf
# Epoch 7: early stopping
# 1-th combination = (True, False, 16, 4, 0.2)
#  train accuracy: [nan, nan] and test accuracy: [nan, nan]
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# No.3 combination:
#
# --------------------------------------------------------------------
#
# Epoch 1: val_loss did not improve from inf
#
# Epoch 2: val_loss did not improve from inf
#
# Epoch 3: val_loss did not improve from inf
#
# Epoch 4: val_loss did not improve from inf
#
# Epoch 5: val_loss did not improve from inf
#
# Epoch 6: val_loss did not improve from inf
#
# Epoch 7: val_loss did not improve from inf
# Epoch 7: early stopping
# 2-th combination = (True, False, 16, 8, 0.1)
#  train accuracy: [nan, nan] and test accuracy: [nan, nan]
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# No.4 combination:
#
# --------------------------------------------------------------------
#
# Epoch 1: val_loss did not improve from inf
#
# Epoch 2: val_loss did not improve from inf
#
# Epoch 3: val_loss did not improve from inf
#
# Epoch 4: val_loss did not improve from inf
#
# Epoch 5: val_loss did not improve from inf
#
# Epoch 6: val_loss did not improve from inf
#
# Epoch 7: val_loss did not improve from inf
# Epoch 7: early stopping
# 3-th combination = (True, False, 16, 8, 0.2)
#  train accuracy: [nan, nan] and test accuracy: [nan, nan]
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# No.5 combination:
#
# --------------------------------------------------------------------
#
# Epoch 1: val_loss did not improve from inf
#
# Epoch 2: val_loss did not improve from inf
#
# Epoch 3: val_loss did not improve from inf
#
# Epoch 4: val_loss did not improve from inf
#
# Epoch 5: val_loss did not improve from inf
#
# Epoch 6: val_loss did not improve from inf
#
# Epoch 7: val_loss did not improve from inf
# Epoch 7: early stopping
# 4-th combination = (True, False, 16, 16, 0.1)
#  train accuracy: [nan, nan] and test accuracy: [nan, nan]
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# No.6 combination:
#
# --------------------------------------------------------------------
#
# Epoch 1: val_loss did not improve from inf
#
# Epoch 2: val_loss did not improve from inf
#
# Epoch 3: val_loss did not improve from inf
#
# Epoch 4: val_loss did not improve from inf
#
# Epoch 5: val_loss did not improve from inf
#
# Epoch 6: val_loss did not improve from inf
#
# Epoch 7: val_loss did not improve from inf
# Epoch 7: early stopping
# 5-th combination = (True, False, 16, 16, 0.2)
#  train accuracy: [nan, nan] and test accuracy: [nan, nan]
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# No.7 combination:
#
# --------------------------------------------------------------------
#
# Epoch 1: val_loss did not improve from inf
#
# Epoch 2: val_loss did not improve from inf
#
# Epoch 3: val_loss did not improve from inf
#
# Epoch 4: val_loss did not improve from inf
#
# Epoch 5: val_loss did not improve from inf
#
# Epoch 6: val_loss did not improve from inf
#
# Epoch 7: val_loss did not improve from inf
# Epoch 7: early stopping
# 6-th combination = (True, False, 32, 4, 0.1)
#  train accuracy: [nan, nan] and test accuracy: [nan, nan]
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# No.8 combination:
#
# --------------------------------------------------------------------
#
# Epoch 1: val_loss did not improve from inf
#
# Epoch 2: val_loss did not improve from inf
#
# Epoch 3: val_loss did not improve from inf
#
# Epoch 4: val_loss did not improve from inf
#
# Epoch 5: val_loss did not improve from inf
#
# Epoch 6: val_loss did not improve from inf
#
# Epoch 7: val_loss did not improve from inf
# Epoch 7: early stopping
# 7-th combination = (True, False, 32, 4, 0.2)
#  train accuracy: [nan, nan] and test accuracy: [nan, nan]
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# No.9 combination:
#
# --------------------------------------------------------------------
#
# Epoch 1: val_loss did not improve from inf
#
# Epoch 2: val_loss did not improve from inf
#
# Epoch 3: val_loss did not improve from inf
#
# Epoch 4: val_loss did not improve from inf
#
# Epoch 5: val_loss did not improve from inf
#
# Epoch 6: val_loss did not improve from inf
#
# Epoch 7: val_loss did not improve from inf
# Epoch 7: early stopping
# 8-th combination = (True, False, 32, 8, 0.1)
#  train accuracy: [nan, nan] and test accuracy: [nan, nan]
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# No.10 combination:
#
# --------------------------------------------------------------------
#
# Epoch 1: val_loss did not improve from inf
#
# Epoch 2: val_loss did not improve from inf
#
# Epoch 3: val_loss did not improve from inf
#
# Epoch 4: val_loss did not improve from inf
#
# Epoch 5: val_loss did not improve from inf
#
# Epoch 6: val_loss did not improve from inf
#
# Epoch 7: val_loss did not improve from inf
# Epoch 7: early stopping
# 9-th combination = (True, False, 32, 8, 0.2)
#  train accuracy: [nan, nan] and test accuracy: [nan, nan]
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# No.11 combination:
#
# --------------------------------------------------------------------
#
# Epoch 1: val_loss did not improve from inf
#
# Epoch 2: val_loss did not improve from inf
#
# Epoch 3: val_loss did not improve from inf
#
# Epoch 4: val_loss did not improve from inf
#
# Epoch 5: val_loss did not improve from inf
#
# Epoch 6: val_loss did not improve from inf
#
# Epoch 7: val_loss did not improve from inf
# Epoch 7: early stopping
# 10-th combination = (True, False, 32, 16, 0.1)
#  train accuracy: [nan, nan] and test accuracy: [nan, nan]
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# No.12 combination:
#
# --------------------------------------------------------------------
# Epoch 1: val_loss did not improve from inf
#
# Epoch 2: val_loss did not improve from inf
#
# Epoch 3: val_loss did not improve from inf
#
# Epoch 4: val_loss did not improve from inf
#
# Epoch 5: val_loss did not improve from inf
#
# Epoch 6: val_loss did not improve from inf
#
# Epoch 7: val_loss did not improve from inf
# Epoch 7: early stopping
# 11-th combination = (True, False, 32, 16, 0.2)
#  train accuracy: [nan, nan] and test accuracy: [nan, nan]
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# No.13 combination:
#
# --------------------------------------------------------------------
#
# Epoch 1: val_loss did not improve from inf
#
# Epoch 2: val_loss did not improve from inf
#
# Epoch 3: val_loss did not improve from inf
#
# Epoch 4: val_loss did not improve from inf
#
# Epoch 5: val_loss did not improve from inf
#
# Epoch 6: val_loss did not improve from inf
#
# Epoch 7: val_loss did not improve from inf
# Epoch 7: early stopping
# 12-th combination = (True, False, 64, 4, 0.1)
#  train accuracy: [nan, nan] and test accuracy: [nan, nan]
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# No.14 combination:
#
# --------------------------------------------------------------------
#
# Epoch 1: val_loss did not improve from inf
#
# Epoch 2: val_loss did not improve from inf
#
# Epoch 3: val_loss did not improve from inf
#
# Epoch 4: val_loss did not improve from inf
#
# Epoch 5: val_loss did not improve from inf
#
# Epoch 6: val_loss did not improve from inf
#
# Epoch 7: val_loss did not improve from inf
# Epoch 7: early stopping
# 13-th combination = (True, False, 64, 4, 0.2)
#  train accuracy: [nan, nan] and test accuracy: [nan, nan]
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# No.15 combination:
#
# --------------------------------------------------------------------
#
# Epoch 1: val_loss did not improve from inf
#
# Epoch 2: val_loss did not improve from inf
#
# Epoch 3: val_loss did not improve from inf
#
# Epoch 4: val_loss did not improve from inf
#
# Epoch 5: val_loss did not improve from inf
#
# Epoch 6: val_loss did not improve from inf
#
# Epoch 7: val_loss did not improve from inf
# Epoch 7: early stopping
# 14-th combination = (True, False, 64, 8, 0.1)
#  train accuracy: [nan, nan] and test accuracy: [nan, nan]
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# No.16 combination:
#
# --------------------------------------------------------------------
#
# Epoch 1: val_loss did not improve from inf
#
# Epoch 2: val_loss did not improve from inf
#
# Epoch 3: val_loss did not improve from inf
#
# Epoch 4: val_loss did not improve from inf
#
# Epoch 5: val_loss did not improve from inf
#
# Epoch 6: val_loss did not improve from inf
#
# Epoch 7: val_loss did not improve from inf
# Epoch 7: early stopping
# 15-th combination = (True, False, 64, 8, 0.2)
#  train accuracy: [nan, nan] and test accuracy: [nan, nan]
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# No.17 combination:
#
# --------------------------------------------------------------------
#
# Epoch 1: val_loss did not improve from inf
#
# Epoch 2: val_loss did not improve from inf
#
# Epoch 3: val_loss did not improve from inf
#
# Epoch 4: val_loss did not improve from inf
#
# Epoch 5: val_loss did not improve from inf
#
# Epoch 6: val_loss did not improve from inf
#
# Epoch 7: val_loss did not improve from inf
# Epoch 7: early stopping
# 16-th combination = (True, False, 64, 16, 0.1)
#  train accuracy: [nan, nan] and test accuracy: [nan, nan]
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# No.18 combination:
#
# --------------------------------------------------------------------
#
# Epoch 1: val_loss did not improve from inf
#
# Epoch 2: val_loss did not improve from inf
#
# Epoch 3: val_loss did not improve from inf
#
# Epoch 4: val_loss did not improve from inf
#
# Epoch 5: val_loss did not improve from inf
#
# Epoch 6: val_loss did not improve from inf
#
# Epoch 7: val_loss did not improve from inf
# Epoch 7: early stopping
# 17-th combination = (True, False, 64, 16, 0.2)
#  train accuracy: [nan, nan] and test accuracy: [nan, nan]
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# No.19 combination:
#
# --------------------------------------------------------------------
#
# Epoch 1: val_loss did not improve from inf
#
# Epoch 2: val_loss did not improve from inf
#
# Epoch 3: val_loss did not improve from inf
#
# Epoch 4: val_loss did not improve from inf
#
# Epoch 5: val_loss did not improve from inf
#
# Epoch 6: val_loss did not improve from inf
#
# Epoch 7: val_loss did not improve from inf
# Epoch 7: early stopping
# 18-th combination = (False, False, 16, 4, 0.1)
#  train accuracy: [nan, nan] and test accuracy: [nan, nan]
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# No.20 combination:
#
# --------------------------------------------------------------------
#
# Epoch 1: val_loss did not improve from inf
#
# Epoch 2: val_loss did not improve from inf
#
# Epoch 3: val_loss did not improve from inf
#
# Epoch 4: val_loss did not improve from inf
#
# Epoch 5: val_loss did not improve from inf
#
# Epoch 6: val_loss did not improve from inf
#
# Epoch 7: val_loss did not improve from inf
# Epoch 7: early stopping
# 19-th combination = (False, False, 16, 4, 0.2)
#  train accuracy: [nan, nan] and test accuracy: [nan, nan]
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# No.21 combination:
#
# --------------------------------------------------------------------
#
# Epoch 1: val_loss did not improve from inf
#
# Epoch 2: val_loss did not improve from inf
#
# Epoch 3: val_loss did not improve from inf
#
# Epoch 4: val_loss did not improve from inf
#
# Epoch 5: val_loss did not improve from inf
#
# Epoch 6: val_loss did not improve from inf
#
# Epoch 7: val_loss did not improve from inf
# Epoch 7: early stopping
# 20-th combination = (False, False, 16, 8, 0.1)
#  train accuracy: [nan, nan] and test accuracy: [nan, nan]
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# No.22 combination:
#
# --------------------------------------------------------------------
#
# Epoch 1: val_loss did not improve from inf
#
# Epoch 2: val_loss did not improve from inf
#
# Epoch 3: val_loss did not improve from inf
#
# Epoch 4: val_loss did not improve from inf
#
# Epoch 5: val_loss did not improve from inf
#
# Epoch 6: val_loss did not improve from inf
#
# Epoch 7: val_loss did not improve from inf
# Epoch 7: early stopping
# 21-th combination = (False, False, 16, 8, 0.2)
#  train accuracy: [nan, nan] and test accuracy: [nan, nan]
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# No.23 combination:
#
# --------------------------------------------------------------------
#
# Epoch 1: val_loss did not improve from inf
#
# Epoch 2: val_loss did not improve from inf
#
# Epoch 3: val_loss did not improve from inf
#
# Epoch 4: val_loss did not improve from inf
#
# Epoch 5: val_loss did not improve from inf
#
# Epoch 6: val_loss did not improve from inf
#
# Epoch 7: val_loss did not improve from inf
# Epoch 7: early stopping
# 22-th combination = (False, False, 16, 16, 0.1)
#  train accuracy: [nan, nan] and test accuracy: [nan, nan]
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# No.24 combination:
#
# --------------------------------------------------------------------
#
# Epoch 1: val_loss did not improve from inf
#
# Epoch 2: val_loss did not improve from inf
#
# Epoch 3: val_loss did not improve from inf
#
# Epoch 4: val_loss did not improve from inf
#
# Epoch 5: val_loss did not improve from inf
# Epoch 6: val_loss did not improve from inf
#
# Epoch 7: val_loss did not improve from inf
# Epoch 7: early stopping
# 23-th combination = (False, False, 16, 16, 0.2)
#  train accuracy: [nan, nan] and test accuracy: [nan, nan]
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# No.25 combination:
#
# --------------------------------------------------------------------
#
# Epoch 1: val_loss did not improve from inf
#
# Epoch 2: val_loss did not improve from inf
#
# Epoch 3: val_loss did not improve from inf
#
# Epoch 4: val_loss did not improve from inf
#
# Epoch 5: val_loss did not improve from inf
#
# Epoch 6: val_loss did not improve from inf
#
# Epoch 7: val_loss did not improve from inf
# Epoch 7: early stopping
# 24-th combination = (False, False, 32, 4, 0.1)
#  train accuracy: [nan, nan] and test accuracy: [nan, nan]
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# No.26 combination:
#
# --------------------------------------------------------------------
#
# Epoch 1: val_loss did not improve from inf
#
# Epoch 2: val_loss did not improve from inf
#
# Epoch 3: val_loss did not improve from inf
#
# Epoch 4: val_loss did not improve from inf
#
# Epoch 5: val_loss did not improve from inf
#
# Epoch 6: val_loss did not improve from inf
#
# Epoch 7: val_loss did not improve from inf
# Epoch 7: early stopping
# 25-th combination = (False, False, 32, 4, 0.2)
#  train accuracy: [nan, nan] and test accuracy: [nan, nan]
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# No.27 combination:
#
# --------------------------------------------------------------------
#
# Epoch 1: val_loss did not improve from inf
#
# Epoch 2: val_loss did not improve from inf
#
# Epoch 3: val_loss did not improve from inf
#
# Epoch 4: val_loss did not improve from inf
#
# Epoch 5: val_loss did not improve from inf
#
# Epoch 6: val_loss did not improve from inf
#
# Epoch 7: val_loss did not improve from inf
# Epoch 7: early stopping
# 26-th combination = (False, False, 32, 8, 0.1)
#  train accuracy: [nan, nan] and test accuracy: [nan, nan]
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# No.28 combination:
#
# --------------------------------------------------------------------
#
# Epoch 1: val_loss did not improve from inf
#
# Epoch 2: val_loss did not improve from inf
#
# Epoch 3: val_loss did not improve from inf
#
# Epoch 4: val_loss did not improve from inf
#
# Epoch 5: val_loss did not improve from inf
#
# Epoch 6: val_loss did not improve from inf
#
# Epoch 7: val_loss did not improve from inf
# Epoch 7: early stopping
# 27-th combination = (False, False, 32, 8, 0.2)
#  train accuracy: [nan, nan] and test accuracy: [nan, nan]
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# No.29 combination:
#
# --------------------------------------------------------------------
#
# Epoch 1: val_loss did not improve from inf
#
# Epoch 2: val_loss did not improve from inf
#
# Epoch 3: val_loss did not improve from inf
#
# Epoch 4: val_loss did not improve from inf
#
# Epoch 5: val_loss did not improve from inf
#
# Epoch 6: val_loss did not improve from inf
#
# Epoch 7: val_loss did not improve from inf
# Epoch 7: early stopping
# 28-th combination = (False, False, 32, 16, 0.1)
#  train accuracy: [nan, nan] and test accuracy: [nan, nan]
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# No.30 combination:
#
# --------------------------------------------------------------------
#
# Epoch 1: val_loss did not improve from inf
#
# Epoch 2: val_loss did not improve from inf
#
# Epoch 3: val_loss did not improve from inf
#
# Epoch 4: val_loss did not improve from inf
#
# Epoch 5: val_loss did not improve from inf
#
# Epoch 6: val_loss did not improve from inf
#
# Epoch 7: val_loss did not improve from inf
# Epoch 7: early stopping
# 29-th combination = (False, False, 32, 16, 0.2)
#  train accuracy: [nan, nan] and test accuracy: [nan, nan]
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# No.31 combination:
#
# --------------------------------------------------------------------
#
# Epoch 1: val_loss did not improve from inf
#
# Epoch 2: val_loss did not improve from inf
#
# Epoch 3: val_loss did not improve from inf
#
# Epoch 4: val_loss did not improve from inf
#
# Epoch 5: val_loss did not improve from inf
#
# Epoch 6: val_loss did not improve from inf
#
# Epoch 7: val_loss did not improve from inf
# Epoch 7: early stopping
# 30-th combination = (False, False, 64, 4, 0.1)
#  train accuracy: [nan, nan] and test accuracy: [nan, nan]
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# No.32 combination:
#
# --------------------------------------------------------------------
#
# Epoch 1: val_loss did not improve from inf
#
# Epoch 2: val_loss did not improve from inf
#
# Epoch 3: val_loss did not improve from inf
#
# Epoch 4: val_loss did not improve from inf
#
# Epoch 5: val_loss did not improve from inf
#
# Epoch 6: val_loss did not improve from inf
#
# Epoch 7: val_loss did not improve from inf
# Epoch 7: early stopping
# 31-th combination = (False, False, 64, 4, 0.2)
#  train accuracy: [nan, nan] and test accuracy: [nan, nan]
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# No.33 combination:
#
# --------------------------------------------------------------------
#
# Epoch 1: val_loss did not improve from inf
#
# Epoch 2: val_loss did not improve from inf
#
# Epoch 3: val_loss did not improve from inf
#
# Epoch 4: val_loss did not improve from inf
#
# Epoch 5: val_loss did not improve from inf
#
# Epoch 6: val_loss did not improve from inf
#
# Epoch 7: val_loss did not improve from inf
# Epoch 7: early stopping
# 32-th combination = (False, False, 64, 8, 0.1)
#  train accuracy: [nan, nan] and test accuracy: [nan, nan]
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# No.34 combination:
#
# --------------------------------------------------------------------
#
# Epoch 1: val_loss did not improve from inf
#
# Epoch 2: val_loss did not improve from inf
#
# Epoch 3: val_loss did not improve from inf
#
# Epoch 4: val_loss did not improve from inf
#
# Epoch 5: val_loss did not improve from inf
#
# Epoch 6: val_loss did not improve from inf
#
# Epoch 7: val_loss did not improve from inf
# Epoch 7: early stopping
# 33-th combination = (False, False, 64, 8, 0.2)
#  train accuracy: [nan, nan] and test accuracy: [nan, nan]
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# No.35 combination:
#
# --------------------------------------------------------------------
#
# Epoch 1: val_loss did not improve from inf
#
# Epoch 2: val_loss did not improve from inf
#
# Epoch 3: val_loss did not improve from inf
#
# Epoch 4: val_loss did not improve from inf
#
# Epoch 5: val_loss did not improve from inf
#
# Epoch 6: val_loss did not improve from inf
#
# Epoch 7: val_loss did not improve from inf
# Epoch 7: early stopping
# 34-th combination = (False, False, 64, 16, 0.1)
#  train accuracy: [nan, nan] and test accuracy: [nan, nan]
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# No.36 combination:
#
# --------------------------------------------------------------------
#
# Epoch 1: val_loss did not improve from inf
#
# Epoch 2: val_loss did not improve from inf
#
# Epoch 3: val_loss did not improve from inf
#
# Epoch 4: val_loss did not improve from inf
#
# Epoch 5: val_loss did not improve from inf
#
# Epoch 6: val_loss did not improve from inf
#
# Epoch 7: val_loss did not improve from inf
# Epoch 7: early stopping
# 35-th combination = (False, False, 64, 16, 0.2)
#  train accuracy: [nan, nan] and test accuracy: [nan, nan]
# --------------------------------------------------------------------
# --------------------------------------------------------------------

# %%
config2 = [[True,False], [False], [16, 32, 64], [4, 8, 16], [0.1, 0.2]] 
hist2 = LSTM_HyperParameter_Tuning(X_train2, y_train2, X_test2, y_test2,config2)  # change x_train shape
# Out:
# [(True, False, 16, 4, 0.1), (True, False, 16, 4, 0.2), (True, False, 16, 8, 0.1), (True, False, 16, 8, 0.2), (True, False, 16, 16, 0.1), (True, False, 16, 16, 0.2), (True, False, 32, 4, 0.1), (True, False, 32, 4, 0.2), (True, False, 32, 8, 0.1), (True, False, 32, 8, 0.2), (True, False, 32, 16, 0.1), (True, False, 32, 16, 0.2), (True, False, 64, 4, 0.1), (True, False, 64, 4, 0.2), (True, False, 64, 8, 0.1), (True, False, 64, 8, 0.2), (True, False, 64, 16, 0.1), (True, False, 64, 16, 0.2), (False, False, 16, 4, 0.1), (False, False, 16, 4, 0.2), (False, False, 16, 8, 0.1), (False, False, 16, 8, 0.2), (False, False, 16, 16, 0.1), (False, False, 16, 16, 0.2), (False, False, 32, 4, 0.1), (False, False, 32, 4, 0.2), (False, False, 32, 8, 0.1), (False, False, 32, 8, 0.2), (False, False, 32, 16, 0.1), (False, False, 32, 16, 0.2), (False, False, 64, 4, 0.1), (False, False, 64, 4, 0.2), (False, False, 64, 8, 0.1), (False, False, 64, 8, 0.2), (False, False, 64, 16, 0.1), (False, False, 64, 16, 0.2)]
#
#
# No.1 combination:
#
# --------------------------------------------------------------------
#
# Epoch 1: val_loss did not improve from inf
#
# Epoch 2: val_loss did not improve from inf
#
# Epoch 3: val_loss did not improve from inf
#
# Epoch 4: val_loss did not improve from inf
#
# Epoch 5: val_loss did not improve from inf
#
# Epoch 6: val_loss did not improve from inf
#
# Epoch 7: val_loss did not improve from inf
# Epoch 7: early stopping
# 0-th combination = (True, False, 16, 4, 0.1)
#  train accuracy: [nan, nan] and test accuracy: [nan, nan]
# --------------------------------------------------------------------
# --------------------------------------------------------------------
# No.2 combination:
#
# --------------------------------------------------------------------
# KeyboardInterrupt

# %% [markdown]
# ## 2.6 Random Forest Regressor

# %%
df_temp_nostore.iloc[:, 2:]
# Out:
#       Holiday_Flag  Temperature  Fuel_Price         CPI  Unemployment  \
# 0                0        42.31       2.572  211.096358         8.106
# 1                1        38.51       2.548  211.242170         8.106
# 2                0        39.93       2.514  211.289143         8.106
# 3                0        46.63       2.561  211.319643         8.106
# 4                0        46.50       2.625  211.350143         8.106
# ...            ...          ...         ...         ...           ...
# 6430             0        64.88       3.997  192.013558         8.684
# 6431             0        64.89       3.985  192.170412         8.667
# 6432             0        54.47       4.000  192.327265         8.667
# 6433             0        56.47       3.969  192.330854         8.667
# 6434             0        58.85       3.882  192.308899         8.667
#
#       stock_price    sp500  loc_0  loc_1  loc_2
# 0        53.45000  1066.19      0      1      0
# 1        52.89999  1075.51      0      1      0
# 2        53.49001  1109.17      0      1      0
# 3        54.07001  1104.49      0      1      0
# 4        54.14000  1138.69      0      1      0
# ...           ...      ...    ...    ...    ...
# 6430     73.80000  1440.67      0      0      1
# 6431     75.13000  1460.93      0      0      1
# 6432     75.81000  1428.59      0      0      1
# 6433     75.62000  1433.19      0      0      1
# 6434     75.11000  1411.94      0      0      1
#
# [6435 rows x 10 columns]

# %%
X = df_temp_nostore.iloc[:, 2:].fillna(method='ffill')
y =df_temp_nostore.iloc[:, 1]

# %%
X_tr, X_te, y_tr, y_te = train_test_split(X, y, test_size=0.3, random_state=2, shuffle=False)

# %%
n_est = [int(n) for n in np.logspace(start=1, stop=3, num=20)]
param_grid_rf = {
    'standardscaler': [StandardScaler(), None],
    'randomforestregressor__max_depth': [80, 90, 100, 110],
    'randomforestregressor__bootstrap': [True, False],
    'randomforestregressor__min_samples_leaf': [3,4,5],
    'randomforestregressor__n_estimators': n_est}

pipeline_rf = make_pipeline(
    StandardScaler(),
    RandomForestRegressor()
)

# %%
rf_grid_cv = GridSearchCV(pipeline_rf, param_grid=param_grid_rf, cv=5, n_jobs=-1)
rf_grid_cv.fit(X_tr, y_tr)
